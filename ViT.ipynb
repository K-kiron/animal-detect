# %% [markdown]
# Lien de téléchargement des données: https://cvml.ista.ac.at/AwA2/
#
# 13GB file : https://cvml.ista.ac.at/AwA2/AwA2-data.zip

# %%
import sys
print(sys.version)
# Out:
# 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]

# %%
import sys
import cv2 # Pour utiliser open_cv, il faut la version de python est 3.7
import os
import csv

import numpy as np 
import pandas as pd 
import math

import torch 
from torch.utils.data import Dataset, DataLoader
import torchvision 
from torchvision.io import read_image
import torchvision.datasets as datasets
import torchvision.transforms as transforms

np.random.seed(0)

# %%
# Constant. Should be the path to the folder named JPEGImages, containing the 33K images in its subfolders.
DATA_FOLDER_PATH = "C:\\Users\\1\\Desktop\\data_ift3710\\Animals_with_Attributes2\\"
JPEGIMAGES_FOLDER_PATH = "C:\\Users\\1\\Desktop\\data_ift3710\\Animals_with_Attributes2\\JPEGImages\\"

# %%
# quick test
test = JPEGIMAGES_FOLDER_PATH+"fox\\fox_10001.jpg"
img = cv2.imread(test) 
print(img.shape) #ndarray
print(type(img))
cv2.imshow('Sample Image from AwA2 dataset',img)
cv2.waitKey(0)
# Out:
# (764, 918, 3)
# <class 'numpy.ndarray'>
# -1

# %%
labels_dirs = os.listdir(JPEGIMAGES_FOLDER_PATH)
print(labels_dirs)
len(labels_dirs) # 50 labels / subdirectories
# Out:
# ['antelope', 'bat', 'beaver', 'blue+whale', 'bobcat', 'buffalo', 'chihuahua', 'chimpanzee', 'collie', 'cow', 'dalmatian', 'deer', 'dolphin', 'elephant', 'fox', 'german+shepherd', 'giant+panda', 'giraffe', 'gorilla', 'grizzly+bear', 'hamster', 'hippopotamus', 'horse', 'humpback+whale', 'killer+whale', 'leopard', 'lion', 'mole', 'moose', 'mouse', 'otter', 'ox', 'persian+cat', 'pig', 'polar+bear', 'rabbit', 'raccoon', 'rat', 'rhinoceros', 'seal', 'sheep', 'siamese+cat', 'skunk', 'spider+monkey', 'squirrel', 'tiger', 'walrus', 'weasel', 'wolf', 'zebra']
# 50

# %% [markdown]
# # Note : Some labels have a low number of images.
#
# ## Possible solutions to explore :
#     Data augmentation : creating new training data by applying random transformations to existing images, such as rotating, cropping, or flipping them.

# %%
def find_num_images_per_label(img_dir = JPEGIMAGES_FOLDER_PATH) -> tuple[dict,dict]: 
    """ 
    USEFUL FOR SAMPLING.
    Return a dict with keys as the 50 labels, and values being the number of images in each subdirectory corresponding to label
    and a second dict with the relative numbers (proportion) for every label compared to the total number of images (useful for sampling)"""
    labels_dirs = os.listdir(img_dir)
    num_images_per_label = dict.fromkeys(labels_dirs)
    proportions_images_per_label = dict.fromkeys(labels_dirs)
    total_num_images = 0

    # Update absolute number of images per label
    for i, label in enumerate(labels_dirs) : 
        specific_label_path = os.path.join(img_dir, labels_dirs[i])
        num_images_label = len(os.listdir(specific_label_path))
        total_num_images += num_images_label
        num_images_per_label[label] = num_images_label

    # Update relative number of images per label (proportion)
    for i, label in enumerate(labels_dirs) : 
        num_images_label = num_images_per_label[label]
        proportion_label = round(num_images_label / total_num_images, 4)
        proportions_images_per_label[label] = proportion_label

    return num_images_per_label, proportions_images_per_label

num_images_per_label, proportions_images_per_label = find_num_images_per_label()
print(num_images_per_label)
print(proportions_images_per_label)
# Out:
# {'antelope': 1046, 'bat': 383, 'beaver': 193, 'blue+whale': 174, 'bobcat': 630, 'buffalo': 895, 'chihuahua': 567, 'chimpanzee': 728, 'collie': 1028, 'cow': 1338, 'dalmatian': 549, 'deer': 1344, 'dolphin': 946, 'elephant': 1038, 'fox': 664, 'german+shepherd': 1033, 'giant+panda': 874, 'giraffe': 1202, 'gorilla': 872, 'grizzly+bear': 852, 'hamster': 779, 'hippopotamus': 684, 'horse': 1645, 'humpback+whale': 709, 'killer+whale': 291, 'leopard': 720, 'lion': 1019, 'mole': 100, 'moose': 704, 'mouse': 185, 'otter': 758, 'ox': 728, 'persian+cat': 747, 'pig': 713, 'polar+bear': 868, 'rabbit': 1088, 'raccoon': 512, 'rat': 310, 'rhinoceros': 696, 'seal': 988, 'sheep': 1420, 'siamese+cat': 500, 'skunk': 188, 'spider+monkey': 291, 'squirrel': 1200, 'tiger': 877, 'walrus': 215, 'weasel': 272, 'wolf': 589, 'zebra': 1170}
# {'antelope': 0.028, 'bat': 0.0103, 'beaver': 0.0052, 'blue+whale': 0.0047, 'bobcat': 0.0169, 'buffalo': 0.024, 'chihuahua': 0.0152, 'chimpanzee': 0.0195, 'collie': 0.0275, 'cow': 0.0359, 'dalmatian': 0.0147, 'deer': 0.036, 'dolphin': 0.0253, 'elephant': 0.0278, 'fox': 0.0178, 'german+shepherd': 0.0277, 'giant+panda': 0.0234, 'giraffe': 0.0322, 'gorilla': 0.0234, 'grizzly+bear': 0.0228, 'hamster': 0.0209, 'hippopotamus': 0.0183, 'horse': 0.0441, 'humpback+whale': 0.019, 'killer+whale': 0.0078, 'leopard': 0.0193, 'lion': 0.0273, 'mole': 0.0027, 'moose': 0.0189, 'mouse': 0.005, 'otter': 0.0203, 'ox': 0.0195, 'persian+cat': 0.02, 'pig': 0.0191, 'polar+bear': 0.0233, 'rabbit': 0.0292, 'raccoon': 0.0137, 'rat': 0.0083, 'rhinoceros': 0.0186, 'seal': 0.0265, 'sheep': 0.038, 'siamese+cat': 0.0134, 'skunk': 0.005, 'spider+monkey': 0.0078, 'squirrel': 0.0322, 'tiger': 0.0235, 'walrus': 0.0058, 'weasel': 0.0073, 'wolf': 0.0158, 'zebra': 0.0313}

# %%
ANNOTATIONS_FILENAME = 'annotations.csv'

def create_annotations_csv_file(annotations_filename = ANNOTATIONS_FILENAME, img_dir = JPEGIMAGES_FOLDER_PATH): 
    """ 
    Create a csv annotations_file, annotations.csv, with two columns, in the format : 
                        path/to/image, label
    
    The annotation csv is necessary for DataLoader.
    """
    
    labels_dirs:list = os.listdir(img_dir)
   
    if os.path.exists(annotations_filename):
        os.remove(annotations_filename)
        print(f'Deleted existent {ANNOTATIONS_FILENAME} file.\n ---------------------------')
    
    with open(annotations_filename, 'w', newline='') as file :
        writer = csv.writer(file, dialect='excel', delimiter=',')

        for i, label in enumerate(labels_dirs) : 

            specific_label_path = os.path.join(img_dir, label)
            images_names = os.listdir(specific_label_path)

            for j, image_name in enumerate(images_names):
                full_path_to_img= os.path.join(specific_label_path, image_name)
                full_path_to_img= os.path.join(label, image_name)

                row = [full_path_to_img, label]
                writer.writerow(row)

    print(f'Sucessfully created {ANNOTATIONS_FILENAME} file.')

#
create_annotations_csv_file()
# Out:
# Deleted existent annotations.csv file.
#  ---------------------------
# Sucessfully created annotations.csv file.

# %%
# labels_in_number = pd.read_csv(DATA_FOLDER_PATH+"classes.txt", delim_whitespace=True,header=None)
labels_dict = {}
with open(DATA_FOLDER_PATH+"classes.txt") as f:
    for line in f:
        # print(line.split())
        (key,val) = line.split()
        labels_dict[val] = int(key)-1
print(labels_dict)
# Out:
# {'antelope': 0, 'grizzly+bear': 1, 'killer+whale': 2, 'beaver': 3, 'dalmatian': 4, 'persian+cat': 5, 'horse': 6, 'german+shepherd': 7, 'blue+whale': 8, 'siamese+cat': 9, 'skunk': 10, 'mole': 11, 'tiger': 12, 'hippopotamus': 13, 'leopard': 14, 'moose': 15, 'spider+monkey': 16, 'humpback+whale': 17, 'elephant': 18, 'gorilla': 19, 'ox': 20, 'fox': 21, 'sheep': 22, 'seal': 23, 'chimpanzee': 24, 'hamster': 25, 'squirrel': 26, 'rhinoceros': 27, 'rabbit': 28, 'bat': 29, 'giraffe': 30, 'wolf': 31, 'chihuahua': 32, 'rat': 33, 'weasel': 34, 'otter': 35, 'buffalo': 36, 'zebra': 37, 'giant+panda': 38, 'deer': 39, 'bobcat': 40, 'pig': 41, 'lion': 42, 'mouse': 43, 'polar+bear': 44, 'collie': 45, 'walrus': 46, 'raccoon': 47, 'cow': 48, 'dolphin': 49}

# %%
class AWA2Dataset(Dataset): # Dataset class to serve as input for the DataLoader.
    """ 
    Dataset class to serve as input for the DataLoader.
    Implements all the required methods and more. 
    """

    def __init__(self, annotations_file=ANNOTATIONS_FILENAME, img_dir=JPEGIMAGES_FOLDER_PATH, 
                transform=None, target_transform=None):
        self.img_labels = pd.read_csv(annotations_file)
        self.img_dir = img_dir
        self.transform = transform
        self.target_transform = target_transform

        numbers_infos_dicts: tuple[dict,dict] = find_num_images_per_label(img_dir=JPEGIMAGES_FOLDER_PATH)
        self.num_images_per_label = numbers_infos_dicts[0]
        self.proportions_images_per_label = numbers_infos_dicts[1]

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        # img_path = self.img_labels.iloc[idx, 0]
        key = self.img_labels.iloc[idx, 1]

        # Mapping the labels from string to tensor
        label = labels_dict[key]

        image = read_image(img_path)
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %%
dataset = AWA2Dataset()
image,label = dataset[4125]



## TODO : Change transforms. Currently this is not useful.
dataset.transform = transforms.Compose([
                        transforms.ToPILImage(),
                        transforms.Resize((224, 224)),
                        transforms.RandomHorizontalFlip(),
                        transforms.Grayscale(num_output_channels=3),
                        transforms.ToTensor(),
                        transforms.Normalize((0.485, 0.456, 0.406), 
                                             (0.229, 0.224, 0.225))])

# Testing. All good
# random_index = np.random.randint(0, len(dataset))
# image, label = dataset[1]
# print(label)
# print(image)
train_size =  int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size,test_size])

# %%
# Experiment with DataLoader. Everything works good
dataloader = DataLoader(dataset = dataset, batch_size=4, shuffle=True)
dataiter = iter(dataloader)
data = next(dataiter)

images, labels = data 
print(labels, images.shape)
# Out:
# tensor([ 1, 38,  6, 15]) torch.Size([4, 3, 224, 224])

# %%
# Training loop example
num_epochs = 2 
batch_size = 4
total_samples = len(dataset)
n_iterations = math.ceil(total_samples/batch_size)
print(total_samples, n_iterations)

dataloader = DataLoader(dataset = dataset, batch_size=batch_size, shuffle=True)

for epoch in range(num_epochs) : 
    # loop over trainloader 
    for i, (inputs, labels) in enumerate(dataloader) : 
        
        # Do forward and backward pass, update the weights 
        if(i+1) % 5 == 0 :
            print(f'epoch {epoch+1} / {num_epochs}, step, {i+1}/{n_iterations}, inputs {inputs.shape}')

        if i==20 : 
            print('Completed')
            break
# Out:
# 37321 9331
# epoch 1 / 2, step, 5/9331, inputs torch.Size([4, 3, 224, 224])
# epoch 1 / 2, step, 10/9331, inputs torch.Size([4, 3, 224, 224])
# epoch 1 / 2, step, 15/9331, inputs torch.Size([4, 3, 224, 224])
# epoch 1 / 2, step, 20/9331, inputs torch.Size([4, 3, 224, 224])
# Completed
# epoch 2 / 2, step, 5/9331, inputs torch.Size([4, 3, 224, 224])
# epoch 2 / 2, step, 10/9331, inputs torch.Size([4, 3, 224, 224])
# epoch 2 / 2, step, 15/9331, inputs torch.Size([4, 3, 224, 224])
# epoch 2 / 2, step, 20/9331, inputs torch.Size([4, 3, 224, 224])
# Completed

# %%
import torch.nn as nn
import timm
from vit_pytorch import ViT

# class ViT(nn.Module):
#     def __init__(self, model_name="vit_large_patch16_224_in21k", pretrained=True):
#         super(ViT, self).__init__()
#         self.vit = timm.create_model(model_name, pretrained=pretrained)
#         # Others variants of ViT can be used as well
#         '''
#         1 --- 'vit_small_patch16_224'
#         2 --- 'vit_base_patch16_224'
#         3 --- 'vit_large_patch16_224',
#         4 --- 'vit_large_patch32_224'
#         5 --- 'vit_deit_base_patch16_224'
#         6 --- 'deit_base_distilled_patch16_224',
#         '''

#         # Change the head depending of the dataset used 
#         self.vit.head = nn.Identity()
#     def forward(self, x):
#         x = self.vit.patch_embed(x)
#         cls_token = self.vit.cls_token.expand(x.shape[0], -1, -1)  
#         if self.vit.dist_token is None:
#             x = torch.cat((cls_token, x), dim=1)
#         else:
#             x = torch.cat((cls_token, self.vit.dist_token.expand(x.shape[0], -1, -1), x), dim=1)
#         x = self.vit.pos_drop(x + self.vit.pos_embed)
#         x = self.vit.blocks(x)
#         x = self.vit.norm(x)
        
#         return x[:, 0], x[:, 1:]
    
train_dataloader = DataLoader(train_dataset, batch_size=8, shuffle= True)
test_dataloader = DataLoader(test_dataset, batch_size=4, shuffle= True)

model = ViT(
    image_size = 224,
    patch_size = 16,
    num_classes = 50,
    dim = 1024,
    depth = 6,
    heads = 8,
    mlp_dim = 2048,
    dropout = 0.1,
    emb_dropout = 0.1
)
loss_fun = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

num_epochs = 2
correct = 0
total = 0
for epoch in range(num_epochs):
    for i, (inputs, labels) in enumerate(train_dataloader):
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_fun(outputs, labels)
        loss.backward()
        optimizer.step()

        #predict
        _,predicted = torch.max(outputs.data,1)
        total += labels.size(0)
        correct += (predicted == labels).squeeze().sum().numpy()

        print(f"Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_dataloader)}], Loss: {loss.item():.4f}, accuracy: {(correct / total)*100:.4f}%")
# Out:
# Epoch [1/2], Step [1/3732], Loss: 4.1338, accuracy: 0.0000%
# Epoch [1/2], Step [2/3732], Loss: 3.7855, accuracy: 6.2500%
# Epoch [1/2], Step [3/3732], Loss: 4.0917, accuracy: 4.1667%
# Epoch [1/2], Step [4/3732], Loss: 4.1595, accuracy: 3.1250%
# Epoch [1/2], Step [5/3732], Loss: 3.7275, accuracy: 5.0000%
# Epoch [1/2], Step [6/3732], Loss: 4.0113, accuracy: 4.1667%
# Epoch [1/2], Step [7/3732], Loss: 4.0093, accuracy: 3.5714%
# Epoch [1/2], Step [8/3732], Loss: 4.1892, accuracy: 3.1250%
# Epoch [1/2], Step [9/3732], Loss: 4.0202, accuracy: 2.7778%
# Epoch [1/2], Step [10/3732], Loss: 3.8448, accuracy: 5.0000%
# Epoch [1/2], Step [11/3732], Loss: 3.8979, accuracy: 4.5455%
# Epoch [1/2], Step [12/3732], Loss: 4.0302, accuracy: 5.2083%
# Epoch [1/2], Step [13/3732], Loss: 4.2779, accuracy: 4.8077%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8240\274604953.py in <module>
#      55     for i, (inputs, labels) in enumerate(train_dataloader):
#      56         optimizer.zero_grad()
# ---> 57         outputs = model(inputs)
#      58         loss = loss_fun(outputs, labels)
#      59         loss.backward()
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\vit_pytorch\vit.py in forward(self, img)
#     122         x = self.dropout(x)
#     123
# --> 124         x = self.transformer(x)
#     125
#     126         x = x.mean(dim = 1) if self.pool == 'mean' else x[:, 0]
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\vit_pytorch\vit.py in forward(self, x)
#      77         for attn, ff in self.layers:
#      78             x = attn(x) + x
# ---> 79             x = ff(x) + x
#      80         return x
#      81
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\vit_pytorch\vit.py in forward(self, x, **kwargs)
#      18         self.fn = fn
#      19     def forward(self, x, **kwargs):
# ---> 20         return self.fn(self.norm(x), **kwargs)
#      21
#      22 class FeedForward(nn.Module):
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\vit_pytorch\vit.py in forward(self, x)
#      31         )
#      32     def forward(self, x):
# ---> 33         return self.net(x)
#      34
#      35 class Attention(nn.Module):
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     215     def forward(self, input):
#     216         for module in self:
# --> 217             input = module(input)
#     218         return input
#     219
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
# model.eval()  # switch to evaluation mode

with torch.no_grad():
    model.eval()
    correct = 0
    total = 0
    for inputs, labels in test_dataloader:
        outputs = model(inputs)
        _,predicted = torch.max(outputs.data,1)
        total += labels.size(0)
        correct += (predicted == labels).squeeze().sum().numpy()

        print(f"test accuracy: {(correct / total)*100:.4f}%")
# Out:
# test accuracy: 0.0000%
# test accuracy: 12.5000%
# test accuracy: 16.6667%
# test accuracy: 18.7500%
# test accuracy: 20.0000%
# test accuracy: 16.6667%
# test accuracy: 14.2857%
# test accuracy: 12.5000%
# test accuracy: 11.1111%
# test accuracy: 10.0000%
# test accuracy: 9.0909%
# test accuracy: 10.4167%
# test accuracy: 9.6154%
# test accuracy: 8.9286%
# test accuracy: 8.3333%
# test accuracy: 9.3750%
# test accuracy: 10.2941%
# test accuracy: 11.1111%
# test accuracy: 11.8421%
# test accuracy: 11.2500%
# test accuracy: 10.7143%
# test accuracy: 12.5000%
# test accuracy: 13.0435%
# test accuracy: 12.5000%
# test accuracy: 13.0000%
# test accuracy: 12.5000%
# test accuracy: 12.0370%
# test accuracy: 11.6071%
# test accuracy: 11.2069%
# test accuracy: 11.6667%
# test accuracy: 12.0968%
# test accuracy: 12.5000%
# test accuracy: 12.8788%
# test accuracy: 13.2353%
# test accuracy: 13.5714%
# test accuracy: 13.1944%
# test accuracy: 13.5135%
# test accuracy: 13.8158%
# test accuracy: 14.1026%
# test accuracy: 13.7500%
# test accuracy: 14.0244%
# test accuracy: 13.6905%
# test accuracy: 13.9535%
# test accuracy: 13.6364%
# test accuracy: 13.3333%
# test accuracy: 13.0435%
# test accuracy: 12.7660%
# test accuracy: 13.0208%
# test accuracy: 12.7551%
# test accuracy: 12.5000%
# test accuracy: 12.7451%
# test accuracy: 12.5000%
# test accuracy: 13.2075%
# test accuracy: 12.9630%
# test accuracy: 13.1818%
# test accuracy: 13.3929%
# test accuracy: 13.5965%
# test accuracy: 14.6552%
# test accuracy: 14.4068%
# test accuracy: 14.5833%
# test accuracy: 14.3443%
# test accuracy: 14.1129%
# test accuracy: 13.8889%
# test accuracy: 14.0625%
# test accuracy: 14.2308%
# test accuracy: 14.0152%
# test accuracy: 14.1791%
# test accuracy: 13.9706%
# test accuracy: 14.1304%
# test accuracy: 13.9286%
# test accuracy: 13.7324%
# test accuracy: 13.5417%
# test accuracy: 13.3562%
# test accuracy: 13.1757%
# test accuracy: 13.3333%
# test accuracy: 13.1579%
# test accuracy: 12.9870%
# test accuracy: 12.8205%
# test accuracy: 12.6582%
# test accuracy: 12.8125%
# test accuracy: 13.2716%
# test accuracy: 13.1098%
# test accuracy: 13.2530%
# test accuracy: 13.0952%
# test accuracy: 12.9412%
# test accuracy: 12.7907%
# test accuracy: 12.9310%
# test accuracy: 13.0682%
# test accuracy: 13.4831%
# test accuracy: 13.6111%
# test accuracy: 13.4615%
# test accuracy: 13.3152%
# test accuracy: 13.1720%
# test accuracy: 13.2979%
# test accuracy: 13.1579%
# test accuracy: 13.2812%
# test accuracy: 13.1443%
# test accuracy: 13.0102%
# test accuracy: 12.8788%
# test accuracy: 13.0000%
# test accuracy: 12.8713%
# test accuracy: 13.2353%
# test accuracy: 13.1068%
# test accuracy: 13.2212%
# test accuracy: 13.5714%
# test accuracy: 13.6792%
# test accuracy: 13.7850%
# test accuracy: 13.8889%
# test accuracy: 13.7615%
# test accuracy: 13.6364%
# test accuracy: 13.7387%
# test accuracy: 13.8393%
# test accuracy: 14.1593%
# test accuracy: 14.0351%
# test accuracy: 14.3478%
# test accuracy: 14.6552%
# test accuracy: 14.5299%
# test accuracy: 14.4068%
# test accuracy: 14.4958%
# test accuracy: 14.3750%
# test accuracy: 14.2562%
# test accuracy: 14.3443%
# test accuracy: 14.4309%
# test accuracy: 14.5161%
# test accuracy: 14.6000%
# test accuracy: 14.6825%
# test accuracy: 14.7638%
# test accuracy: 15.0391%
# test accuracy: 14.9225%
# test accuracy: 15.0000%
# test accuracy: 14.8855%
# test accuracy: 15.1515%
# test accuracy: 15.2256%
# test accuracy: 15.2985%
# test accuracy: 15.1852%
# test accuracy: 15.2574%
# test accuracy: 15.1460%
# test accuracy: 15.0362%
# test accuracy: 15.1079%
# test accuracy: 15.0000%
# test accuracy: 14.8936%
# test accuracy: 14.7887%
# test accuracy: 15.0350%
# test accuracy: 15.1042%
# test accuracy: 15.1724%
# test accuracy: 15.2397%
# test accuracy: 15.1361%
# test accuracy: 15.3716%
# test accuracy: 15.4362%
# test accuracy: 15.5000%
# test accuracy: 15.5629%
# test accuracy: 15.4605%
# test accuracy: 15.3595%
# test accuracy: 15.5844%
# test accuracy: 15.6452%
# test accuracy: 15.5449%
# test accuracy: 15.4459%
# test accuracy: 15.3481%
# test accuracy: 15.5660%
# test accuracy: 15.4688%
# test accuracy: 15.3727%
# test accuracy: 15.4321%
# test accuracy: 15.3374%
# test accuracy: 15.3963%
# test accuracy: 15.3030%
# test accuracy: 15.2108%
# test accuracy: 15.2695%
# test accuracy: 15.1786%
# test accuracy: 15.2367%
# test accuracy: 15.1471%
# test accuracy: 15.0585%
# test accuracy: 15.1163%
# test accuracy: 15.1734%
# test accuracy: 15.2299%
# test accuracy: 15.2857%
# test accuracy: 15.4830%
# test accuracy: 15.3955%
# test accuracy: 15.3090%
# test accuracy: 15.5028%
# test accuracy: 15.4167%
# test accuracy: 15.4696%
# test accuracy: 15.3846%
# test accuracy: 15.4372%
# test accuracy: 15.3533%
# test accuracy: 15.2703%
# test accuracy: 15.3226%
# test accuracy: 15.3743%
# test accuracy: 15.4255%
# test accuracy: 15.4762%
# test accuracy: 15.3947%
# test accuracy: 15.3141%
# test accuracy: 15.2344%
# test accuracy: 15.1554%
# test accuracy: 15.3351%
# test accuracy: 15.3846%
# test accuracy: 15.3061%
# test accuracy: 15.3553%
# test accuracy: 15.5303%
# test accuracy: 15.5779%
# test accuracy: 15.5000%
# test accuracy: 15.5473%
# test accuracy: 15.5941%
# test accuracy: 15.6404%
# test accuracy: 15.6863%
# test accuracy: 15.6098%
# test accuracy: 15.5340%
# test accuracy: 15.5797%
# test accuracy: 15.6250%
# test accuracy: 15.5502%
# test accuracy: 15.4762%
# test accuracy: 15.4028%
# test accuracy: 15.3302%
# test accuracy: 15.3756%
# test accuracy: 15.3037%
# test accuracy: 15.3488%
# test accuracy: 15.2778%
# test accuracy: 15.2074%
# test accuracy: 15.3670%
# test accuracy: 15.4110%
# test accuracy: 15.4545%
# test accuracy: 15.3846%
# test accuracy: 15.4279%
# test accuracy: 15.4709%
# test accuracy: 15.4018%
# test accuracy: 15.4444%
# test accuracy: 15.3761%
# test accuracy: 15.3084%
# test accuracy: 15.2412%
# test accuracy: 15.2838%
# test accuracy: 15.2174%
# test accuracy: 15.2597%
# test accuracy: 15.1940%
# test accuracy: 15.3433%
# test accuracy: 15.2778%
# test accuracy: 15.4255%
# test accuracy: 15.5720%
# test accuracy: 15.6118%
# test accuracy: 15.5462%
# test accuracy: 15.4812%
# test accuracy: 15.4167%
# test accuracy: 15.5602%
# test accuracy: 15.4959%
# test accuracy: 15.5350%
# test accuracy: 15.4713%
# test accuracy: 15.4082%
# test accuracy: 15.3455%
# test accuracy: 15.2834%
# test accuracy: 15.2218%
# test accuracy: 15.2610%
# test accuracy: 15.2000%
# test accuracy: 15.2390%
# test accuracy: 15.1786%
# test accuracy: 15.3162%
# test accuracy: 15.2559%
# test accuracy: 15.2941%
# test accuracy: 15.4297%
# test accuracy: 15.3696%
# test accuracy: 15.3101%
# test accuracy: 15.5405%
# test accuracy: 15.4808%
# test accuracy: 15.4215%
# test accuracy: 15.3626%
# test accuracy: 15.3042%
# test accuracy: 15.3409%
# test accuracy: 15.3774%
# test accuracy: 15.4135%
# test accuracy: 15.4494%
# test accuracy: 15.4851%
# test accuracy: 15.4275%
# test accuracy: 15.4630%
# test accuracy: 15.4059%
# test accuracy: 15.5331%
# test accuracy: 15.4762%
# test accuracy: 15.5109%
# test accuracy: 15.5455%
# test accuracy: 15.5797%
# test accuracy: 15.5235%
# test accuracy: 15.5576%
# test accuracy: 15.5914%
# test accuracy: 15.6250%
# test accuracy: 15.6584%
# test accuracy: 15.8688%
# test accuracy: 15.9894%
# test accuracy: 16.1092%
# test accuracy: 16.0526%
# test accuracy: 16.0839%
# test accuracy: 16.1150%
# test accuracy: 16.0590%
# test accuracy: 16.0900%
# test accuracy: 16.0345%
# test accuracy: 16.0653%
# test accuracy: 16.0959%
# test accuracy: 16.1263%
# test accuracy: 16.2415%
# test accuracy: 16.2712%
# test accuracy: 16.2162%
# test accuracy: 16.1616%
# test accuracy: 16.1913%
# test accuracy: 16.1371%
# test accuracy: 16.0833%
# test accuracy: 16.0299%
# test accuracy: 16.0596%
# test accuracy: 16.0066%
# test accuracy: 16.0362%
# test accuracy: 16.0656%
# test accuracy: 16.0948%
# test accuracy: 16.1238%
# test accuracy: 16.1526%
# test accuracy: 16.1003%
# test accuracy: 16.1290%
# test accuracy: 16.1576%
# test accuracy: 16.1058%
# test accuracy: 16.1342%
# test accuracy: 16.1624%
# test accuracy: 16.1905%
# test accuracy: 16.2184%
# test accuracy: 16.2461%
# test accuracy: 16.1950%
# test accuracy: 16.1442%
# test accuracy: 16.2500%
# test accuracy: 16.1994%
# test accuracy: 16.1491%
# test accuracy: 16.1765%
# test accuracy: 16.2037%
# test accuracy: 16.1538%
# test accuracy: 16.1043%
# test accuracy: 16.1315%
# test accuracy: 16.0823%
# test accuracy: 16.0334%
# test accuracy: 16.0606%
# test accuracy: 16.1631%
# test accuracy: 16.1898%
# test accuracy: 16.1411%
# test accuracy: 16.2425%
# test accuracy: 16.2687%
# test accuracy: 16.2946%
# test accuracy: 16.2463%
# test accuracy: 16.2722%
# test accuracy: 16.2979%
# test accuracy: 16.2500%
# test accuracy: 16.3490%
# test accuracy: 16.4474%
# test accuracy: 16.4723%
# test accuracy: 16.4244%
# test accuracy: 16.5217%
# test accuracy: 16.5462%
# test accuracy: 16.6427%
# test accuracy: 16.6667%
# test accuracy: 16.6905%
# test accuracy: 16.6429%
# test accuracy: 16.5954%
# test accuracy: 16.5483%
# test accuracy: 16.6431%
# test accuracy: 16.7373%
# test accuracy: 16.9014%
# test accuracy: 16.9242%
# test accuracy: 17.0168%
# test accuracy: 17.1089%
# test accuracy: 17.0613%
# test accuracy: 17.0833%
# test accuracy: 17.1745%
# test accuracy: 17.2652%
# test accuracy: 17.3554%
# test accuracy: 17.3764%
# test accuracy: 17.3288%
# test accuracy: 17.3497%
# test accuracy: 17.3025%
# test accuracy: 17.3913%
# test accuracy: 17.4119%
# test accuracy: 17.3649%
# test accuracy: 17.3181%
# test accuracy: 17.2715%
# test accuracy: 17.2252%
# test accuracy: 17.2460%
# test accuracy: 17.2000%
# test accuracy: 17.2207%
# test accuracy: 17.2414%
# test accuracy: 17.1958%
# test accuracy: 17.2164%
# test accuracy: 17.1711%
# test accuracy: 17.1260%
# test accuracy: 17.2120%
# test accuracy: 17.2324%
# test accuracy: 17.3177%
# test accuracy: 17.3377%
# test accuracy: 17.2927%
# test accuracy: 17.3127%
# test accuracy: 17.2680%
# test accuracy: 17.2237%
# test accuracy: 17.2436%
# test accuracy: 17.1995%
# test accuracy: 17.2832%
# test accuracy: 17.2392%
# test accuracy: 17.1954%
# test accuracy: 17.1519%
# test accuracy: 17.1086%
# test accuracy: 17.1914%
# test accuracy: 17.3367%
# test accuracy: 17.2932%
# test accuracy: 17.2500%
# test accuracy: 17.2070%
# test accuracy: 17.2264%
# test accuracy: 17.2457%
# test accuracy: 17.2649%
# test accuracy: 17.2840%
# test accuracy: 17.2414%
# test accuracy: 17.3219%
# test accuracy: 17.3407%
# test accuracy: 17.3594%
# test accuracy: 17.3171%
# test accuracy: 17.2749%
# test accuracy: 17.2937%
# test accuracy: 17.2518%
# test accuracy: 17.3309%
# test accuracy: 17.3494%
# test accuracy: 17.3077%
# test accuracy: 17.2662%
# test accuracy: 17.2249%
# test accuracy: 17.1838%
# test accuracy: 17.2024%
# test accuracy: 17.1615%
# test accuracy: 17.1801%
# test accuracy: 17.2577%
# test accuracy: 17.3349%
# test accuracy: 17.2941%
# test accuracy: 17.3122%
# test accuracy: 17.2717%
# test accuracy: 17.2313%
# test accuracy: 17.3077%
# test accuracy: 17.2674%
# test accuracy: 17.2274%
# test accuracy: 17.2454%
# test accuracy: 17.2633%
# test accuracy: 17.3387%
# test accuracy: 17.2989%
# test accuracy: 17.2592%
# test accuracy: 17.2769%
# test accuracy: 17.2374%
# test accuracy: 17.2551%
# test accuracy: 17.2159%
# test accuracy: 17.1769%
# test accuracy: 17.1380%
# test accuracy: 17.1558%
# test accuracy: 17.1734%
# test accuracy: 17.1348%
# test accuracy: 17.0964%
# test accuracy: 17.1700%
# test accuracy: 17.1875%
# test accuracy: 17.1492%
# test accuracy: 17.1111%
# test accuracy: 17.1286%
# test accuracy: 17.0907%
# test accuracy: 17.1082%
# test accuracy: 17.1256%
# test accuracy: 17.1978%
# test accuracy: 17.2149%
# test accuracy: 17.1772%
# test accuracy: 17.1943%
# test accuracy: 17.1569%
# test accuracy: 17.1739%
# test accuracy: 17.1909%
# test accuracy: 17.2078%
# test accuracy: 17.2246%
# test accuracy: 17.2414%
# test accuracy: 17.3656%
# test accuracy: 17.3283%
# test accuracy: 17.3448%
# test accuracy: 17.3077%
# test accuracy: 17.2708%
# test accuracy: 17.2872%
# test accuracy: 17.2505%
# test accuracy: 17.2140%
# test accuracy: 17.2304%
# test accuracy: 17.2468%
# test accuracy: 17.3158%
# test accuracy: 17.3845%
# test accuracy: 17.3480%
# test accuracy: 17.3117%
# test accuracy: 17.2756%
# test accuracy: 17.2396%
# test accuracy: 17.2557%
# test accuracy: 17.2199%
# test accuracy: 17.1843%
# test accuracy: 17.1488%
# test accuracy: 17.2680%
# test accuracy: 17.3868%
# test accuracy: 17.4025%
# test accuracy: 17.4180%
# test accuracy: 17.3824%
# test accuracy: 17.3980%
# test accuracy: 17.3625%
# test accuracy: 17.3272%
# test accuracy: 17.2921%
# test accuracy: 17.2571%
# test accuracy: 17.2222%
# test accuracy: 17.1875%
# test accuracy: 17.1529%
# test accuracy: 17.1185%
# test accuracy: 17.1343%
# test accuracy: 17.1500%
# test accuracy: 17.1158%
# test accuracy: 17.0817%
# test accuracy: 17.0974%
# test accuracy: 17.1131%
# test accuracy: 17.0792%
# test accuracy: 17.0949%
# test accuracy: 17.1598%
# test accuracy: 17.1752%
# test accuracy: 17.1415%
# test accuracy: 17.1078%
# test accuracy: 17.0744%
# test accuracy: 17.0898%
# test accuracy: 17.0565%
# test accuracy: 17.1206%
# test accuracy: 17.1359%
# test accuracy: 17.1027%
# test accuracy: 17.0696%
# test accuracy: 17.0367%
# test accuracy: 17.1002%
# test accuracy: 17.0673%
# test accuracy: 17.0345%
# test accuracy: 17.0019%
# test accuracy: 16.9694%
# test accuracy: 16.9847%
# test accuracy: 17.0476%
# test accuracy: 17.0627%
# test accuracy: 17.0304%
# test accuracy: 17.0455%
# test accuracy: 17.0132%
# test accuracy: 17.0283%
# test accuracy: 17.0433%
# test accuracy: 17.1053%
# test accuracy: 17.0732%
# test accuracy: 17.0880%
# test accuracy: 17.0561%
# test accuracy: 17.0243%
# test accuracy: 17.0391%
# test accuracy: 17.0539%
# test accuracy: 17.1150%
# test accuracy: 17.1759%
# test accuracy: 17.2366%
# test accuracy: 17.2048%
# test accuracy: 17.2192%
# test accuracy: 17.2794%
# test accuracy: 17.2936%
# test accuracy: 17.3077%
# test accuracy: 17.3675%
# test accuracy: 17.3358%
# test accuracy: 17.3953%
# test accuracy: 17.4545%
# test accuracy: 17.4682%
# test accuracy: 17.4366%
# test accuracy: 17.4503%
# test accuracy: 17.4639%
# test accuracy: 17.4324%
# test accuracy: 17.4011%
# test accuracy: 17.3698%
# test accuracy: 17.3387%
# test accuracy: 17.3524%
# test accuracy: 17.3214%
# test accuracy: 17.3351%
# test accuracy: 17.3932%
# test accuracy: 17.3623%
# test accuracy: 17.3759%
# test accuracy: 17.3451%
# test accuracy: 17.4028%
# test accuracy: 17.3721%
# test accuracy: 17.3856%
# test accuracy: 17.3550%
# test accuracy: 17.3246%
# test accuracy: 17.3380%
# test accuracy: 17.3077%
# test accuracy: 17.2775%
# test accuracy: 17.2474%
# test accuracy: 17.2609%
# test accuracy: 17.3177%
# test accuracy: 17.3744%
# test accuracy: 17.3443%
# test accuracy: 17.3143%
# test accuracy: 17.3276%
# test accuracy: 17.3408%
# test accuracy: 17.3110%
# test accuracy: 17.3242%
# test accuracy: 17.2945%
# test accuracy: 17.2650%
# test accuracy: 17.2782%
# test accuracy: 17.2913%
# test accuracy: 17.3469%
# test accuracy: 17.4024%
# test accuracy: 17.3729%
# test accuracy: 17.3858%
# test accuracy: 17.3986%
# test accuracy: 17.3693%
# test accuracy: 17.3401%
# test accuracy: 17.3109%
# test accuracy: 17.3658%
# test accuracy: 17.3786%
# test accuracy: 17.3495%
# test accuracy: 17.3205%
# test accuracy: 17.3333%
# test accuracy: 17.3045%
# test accuracy: 17.3588%
# test accuracy: 17.3715%
# test accuracy: 17.3427%
# test accuracy: 17.4380%
# test accuracy: 17.4505%
# test accuracy: 17.4217%
# test accuracy: 17.3931%
# test accuracy: 17.4466%
# test accuracy: 17.4590%
# test accuracy: 17.4714%
# test accuracy: 17.4428%
# test accuracy: 17.4144%
# test accuracy: 17.4267%
# test accuracy: 17.4390%
# test accuracy: 17.4107%
# test accuracy: 17.3825%
# test accuracy: 17.3544%
# test accuracy: 17.3667%
# test accuracy: 17.3790%
# test accuracy: 17.3510%
# test accuracy: 17.3232%
# test accuracy: 17.3355%
# test accuracy: 17.3077%
# test accuracy: 17.3200%
# test accuracy: 17.2923%
# test accuracy: 17.2648%
# test accuracy: 17.2771%
# test accuracy: 17.2496%
# test accuracy: 17.3016%
# test accuracy: 17.3138%
# test accuracy: 17.3259%
# test accuracy: 17.2986%
# test accuracy: 17.2713%
# test accuracy: 17.2441%
# test accuracy: 17.2170%
# test accuracy: 17.2684%
# test accuracy: 17.3197%
# test accuracy: 17.3318%
# test accuracy: 17.3047%
# test accuracy: 17.2777%
# test accuracy: 17.2897%
# test accuracy: 17.3017%
# test accuracy: 17.2748%
# test accuracy: 17.2481%
# test accuracy: 17.2601%
# test accuracy: 17.2334%
# test accuracy: 17.2454%
# test accuracy: 17.2573%
# test accuracy: 17.2692%
# test accuracy: 17.2427%
# test accuracy: 17.2163%
# test accuracy: 17.1899%
# test accuracy: 17.1636%
# test accuracy: 17.2137%
# test accuracy: 17.2637%
# test accuracy: 17.2755%
# test accuracy: 17.2492%
# test accuracy: 17.2610%
# test accuracy: 17.2727%
# test accuracy: 17.2844%
# test accuracy: 17.2583%
# test accuracy: 17.2323%
# test accuracy: 17.2440%
# test accuracy: 17.2180%
# test accuracy: 17.2673%
# test accuracy: 17.2414%
# test accuracy: 17.2156%
# test accuracy: 17.1898%
# test accuracy: 17.1642%
# test accuracy: 17.1386%
# test accuracy: 17.1131%
# test accuracy: 17.0877%
# test accuracy: 17.0623%
# test accuracy: 17.0741%
# test accuracy: 17.0858%
# test accuracy: 17.0606%
# test accuracy: 17.0723%
# test accuracy: 17.1208%
# test accuracy: 17.1691%
# test accuracy: 17.1439%
# test accuracy: 17.1188%
# test accuracy: 17.1669%
# test accuracy: 17.1418%
# test accuracy: 17.1533%
# test accuracy: 17.1283%
# test accuracy: 17.1397%
# test accuracy: 17.1148%
# test accuracy: 17.1626%
# test accuracy: 17.1739%
# test accuracy: 17.1491%
# test accuracy: 17.2327%
# test accuracy: 17.2439%
# test accuracy: 17.2550%
# test accuracy: 17.2302%
# test accuracy: 17.3132%
# test accuracy: 17.3242%
# test accuracy: 17.2994%
# test accuracy: 17.2747%
# test accuracy: 17.2500%
# test accuracy: 17.2611%
# test accuracy: 17.3077%
# test accuracy: 17.3542%
# test accuracy: 17.3651%
# test accuracy: 17.3404%
# test accuracy: 17.3867%
# test accuracy: 17.3621%
# test accuracy: 17.4082%
# test accuracy: 17.4189%
# test accuracy: 17.3944%
# test accuracy: 17.4402%
# test accuracy: 17.4157%
# test accuracy: 17.4264%
# test accuracy: 17.4020%
# test accuracy: 17.3776%
# test accuracy: 17.3534%
# test accuracy: 17.3291%
# test accuracy: 17.3747%
# test accuracy: 17.3853%
# test accuracy: 17.3958%
# test accuracy: 17.4064%
# test accuracy: 17.4169%
# test accuracy: 17.3928%
# test accuracy: 17.3688%
# test accuracy: 17.3448%
# test accuracy: 17.3209%
# test accuracy: 17.3315%
# test accuracy: 17.3077%
# test accuracy: 17.2840%
# test accuracy: 17.2945%
# test accuracy: 17.2709%
# test accuracy: 17.2473%
# test accuracy: 17.2237%
# test accuracy: 17.2343%
# test accuracy: 17.2109%
# test accuracy: 17.1875%
# test accuracy: 17.1981%
# test accuracy: 17.2764%
# test accuracy: 17.2869%
# test accuracy: 17.2635%
# test accuracy: 17.2402%
# test accuracy: 17.2170%
# test accuracy: 17.2275%
# test accuracy: 17.2379%
# test accuracy: 17.2148%
# test accuracy: 17.2252%
# test accuracy: 17.2021%
# test accuracy: 17.2460%
# test accuracy: 17.2563%
# test accuracy: 17.2333%
# test accuracy: 17.2437%
# test accuracy: 17.2207%
# test accuracy: 17.2311%
# test accuracy: 17.2082%
# test accuracy: 17.2185%
# test accuracy: 17.2288%
# test accuracy: 17.2391%
# test accuracy: 17.2164%
# test accuracy: 17.1937%
# test accuracy: 17.1711%
# test accuracy: 17.1485%
# test accuracy: 17.1260%
# test accuracy: 17.1035%
# test accuracy: 17.0812%
# test accuracy: 17.0588%
# test accuracy: 17.0366%
# test accuracy: 17.0143%
# test accuracy: 17.0247%
# test accuracy: 17.0351%
# test accuracy: 17.0130%
# test accuracy: 16.9909%
# test accuracy: 17.0013%
# test accuracy: 16.9793%
# test accuracy: 16.9574%
# test accuracy: 16.9355%
# test accuracy: 16.9459%
# test accuracy: 16.9241%
# test accuracy: 16.9344%
# test accuracy: 16.9769%
# test accuracy: 16.9551%
# test accuracy: 16.9654%
# test accuracy: 16.9757%
# test accuracy: 16.9540%
# test accuracy: 16.9324%
# test accuracy: 16.9108%
# test accuracy: 16.8893%
# test accuracy: 16.8996%
# test accuracy: 16.8782%
# test accuracy: 16.8568%
# test accuracy: 16.8671%
# test accuracy: 16.8458%
# test accuracy: 16.8561%
# test accuracy: 16.8979%
# test accuracy: 16.9081%
# test accuracy: 16.9182%
# test accuracy: 16.8970%
# test accuracy: 16.9699%
# test accuracy: 16.9799%
# test accuracy: 16.9900%
# test accuracy: 17.0000%
# test accuracy: 17.0100%
# test accuracy: 16.9888%
# test accuracy: 16.9676%
# test accuracy: 16.9776%
# test accuracy: 17.0186%
# test accuracy: 16.9975%
# test accuracy: 16.9765%
# test accuracy: 17.0173%
# test accuracy: 17.0581%
# test accuracy: 17.0988%
# test accuracy: 17.0777%
# test accuracy: 17.0567%
# test accuracy: 17.0664%
# test accuracy: 17.0762%
# test accuracy: 17.0552%
# test accuracy: 17.0343%
# test accuracy: 17.0441%
# test accuracy: 17.0844%
# test accuracy: 17.1245%
# test accuracy: 17.1646%
# test accuracy: 17.1437%
# test accuracy: 17.1533%
# test accuracy: 17.1324%
# test accuracy: 17.1117%
# test accuracy: 17.0909%
# test accuracy: 17.1005%
# test accuracy: 17.0798%
# test accuracy: 17.0592%
# test accuracy: 17.0688%
# test accuracy: 17.0783%
# test accuracy: 17.0878%
# test accuracy: 17.0974%
# test accuracy: 17.1068%
# test accuracy: 17.1163%
# test accuracy: 17.1257%
# test accuracy: 17.1651%
# test accuracy: 17.2043%
# test accuracy: 17.2136%
# test accuracy: 17.2229%
# test accuracy: 17.2321%
# test accuracy: 17.2711%
# test accuracy: 17.2506%
# test accuracy: 17.2301%
# test accuracy: 17.2393%
# test accuracy: 17.2485%
# test accuracy: 17.2281%
# test accuracy: 17.2373%
# test accuracy: 17.2170%
# test accuracy: 17.1967%
# test accuracy: 17.1765%
# test accuracy: 17.1857%
# test accuracy: 17.1655%
# test accuracy: 17.1454%
# test accuracy: 17.1838%
# test accuracy: 17.2222%
# test accuracy: 17.2313%
# test accuracy: 17.2987%
# test accuracy: 17.3077%
# test accuracy: 17.3749%
# test accuracy: 17.3837%
# test accuracy: 17.3635%
# test accuracy: 17.3434%
# test accuracy: 17.3233%
# test accuracy: 17.3032%
# test accuracy: 17.3121%
# test accuracy: 17.2921%
# test accuracy: 17.3010%
# test accuracy: 17.3099%
# test accuracy: 17.2900%
# test accuracy: 17.2701%
# test accuracy: 17.3077%
# test accuracy: 17.2878%
# test accuracy: 17.2680%
# test accuracy: 17.2769%
# test accuracy: 17.2571%
# test accuracy: 17.2374%
# test accuracy: 17.2178%
# test accuracy: 17.2267%
# test accuracy: 17.2355%
# test accuracy: 17.2727%
# test accuracy: 17.2531%
# test accuracy: 17.2619%
# test accuracy: 17.2424%
# test accuracy: 17.2511%
# test accuracy: 17.2599%
# test accuracy: 17.2404%
# test accuracy: 17.2210%
# test accuracy: 17.2016%
# test accuracy: 17.2385%
# test accuracy: 17.2472%
# test accuracy: 17.2278%
# test accuracy: 17.2365%
# test accuracy: 17.2452%
# test accuracy: 17.2539%
# test accuracy: 17.2626%
# test accuracy: 17.2433%
# test accuracy: 17.2241%
# test accuracy: 17.2606%
# test accuracy: 17.2692%
# test accuracy: 17.2500%
# test accuracy: 17.2309%
# test accuracy: 17.2395%
# test accuracy: 17.2481%
# test accuracy: 17.2566%
# test accuracy: 17.2652%
# test accuracy: 17.2461%
# test accuracy: 17.2271%
# test accuracy: 17.2632%
# test accuracy: 17.2442%
# test accuracy: 17.2527%
# test accuracy: 17.2338%
# test accuracy: 17.2149%
# test accuracy: 17.1961%
# test accuracy: 17.2046%
# test accuracy: 17.2131%
# test accuracy: 17.1943%
# test accuracy: 17.2028%
# test accuracy: 17.2386%
# test accuracy: 17.2470%
# test accuracy: 17.2554%
# test accuracy: 17.2367%
# test accuracy: 17.2451%
# test accuracy: 17.2264%
# test accuracy: 17.2078%
# test accuracy: 17.2162%
# test accuracy: 17.1976%
# test accuracy: 17.2060%
# test accuracy: 17.2144%
# test accuracy: 17.1959%
# test accuracy: 17.1774%
# test accuracy: 17.1590%
# test accuracy: 17.1406%
# test accuracy: 17.1490%
# test accuracy: 17.1574%
# test accuracy: 17.1658%
# test accuracy: 17.1741%
# test accuracy: 17.2092%
# test accuracy: 17.2175%
# test accuracy: 17.1991%
# test accuracy: 17.2340%
# test accuracy: 17.2689%
# test accuracy: 17.2505%
# test accuracy: 17.2587%
# test accuracy: 17.2669%
# test accuracy: 17.3016%
# test accuracy: 17.3097%
# test accuracy: 17.2914%
# test accuracy: 17.2732%
# test accuracy: 17.2813%
# test accuracy: 17.3158%
# test accuracy: 17.3239%
# test accuracy: 17.3057%
# test accuracy: 17.3137%
# test accuracy: 17.3218%
# test accuracy: 17.3298%
# test accuracy: 17.3379%
# test accuracy: 17.3459%
# test accuracy: 17.3539%
# test accuracy: 17.3618%
# test accuracy: 17.3438%
# test accuracy: 17.3777%
# test accuracy: 17.3857%
# test accuracy: 17.3676%
# test accuracy: 17.4015%
# test accuracy: 17.3834%
# test accuracy: 17.3913%
# test accuracy: 17.3992%
# test accuracy: 17.3812%
# test accuracy: 17.3633%
# test accuracy: 17.3969%
# test accuracy: 17.4047%
# test accuracy: 17.3868%
# test accuracy: 17.3690%
# test accuracy: 17.3511%
# test accuracy: 17.3846%
# test accuracy: 17.3668%
# test accuracy: 17.3490%
# test accuracy: 17.3569%
# test accuracy: 17.3391%
# test accuracy: 17.3214%
# test accuracy: 17.3038%
# test accuracy: 17.3116%
# test accuracy: 17.2940%
# test accuracy: 17.2764%
# test accuracy: 17.2589%
# test accuracy: 17.2667%
# test accuracy: 17.2492%
# test accuracy: 17.2571%
# test accuracy: 17.2649%
# test accuracy: 17.2727%
# test accuracy: 17.2805%
# test accuracy: 17.2631%
# test accuracy: 17.2709%
# test accuracy: 17.2535%
# test accuracy: 17.2362%
# test accuracy: 17.2440%
# test accuracy: 17.2267%
# test accuracy: 17.2345%
# test accuracy: 17.2422%
# test accuracy: 17.2250%
# test accuracy: 17.2078%
# test accuracy: 17.1906%
# test accuracy: 17.1984%
# test accuracy: 17.2062%
# test accuracy: 17.2388%
# test accuracy: 17.2217%
# test accuracy: 17.2294%
# test accuracy: 17.2123%
# test accuracy: 17.2448%
# test accuracy: 17.2772%
# test accuracy: 17.2601%
# test accuracy: 17.2431%
# test accuracy: 17.2754%
# test accuracy: 17.2584%
# test accuracy: 17.2414%
# test accuracy: 17.2490%
# test accuracy: 17.2321%
# test accuracy: 17.2397%
# test accuracy: 17.2718%
# test accuracy: 17.2794%
# test accuracy: 17.2870%
# test accuracy: 17.2945%
# test accuracy: 17.2776%
# test accuracy: 17.2852%
# test accuracy: 17.2683%
# test accuracy: 17.3002%
# test accuracy: 17.3320%
# test accuracy: 17.3152%
# test accuracy: 17.2983%
# test accuracy: 17.3058%
# test accuracy: 17.2890%
# test accuracy: 17.3207%
# test accuracy: 17.3524%
# test accuracy: 17.3356%
# test accuracy: 17.3188%
# test accuracy: 17.3263%
# test accuracy: 17.3337%
# test accuracy: 17.3170%
# test accuracy: 17.3003%
# test accuracy: 17.2837%
# test accuracy: 17.2911%
# test accuracy: 17.2985%
# test accuracy: 17.2819%
# test accuracy: 17.2653%
# test accuracy: 17.2488%
# test accuracy: 17.2801%
# test accuracy: 17.2875%
# test accuracy: 17.2710%
# test accuracy: 17.2545%
# test accuracy: 17.2619%
# test accuracy: 17.2455%
# test accuracy: 17.2291%
# test accuracy: 17.2602%
# test accuracy: 17.2438%
# test accuracy: 17.2275%
# test accuracy: 17.2348%
# test accuracy: 17.2185%
# test accuracy: 17.2023%
# test accuracy: 17.2096%
# test accuracy: 17.1934%
# test accuracy: 17.2008%
# test accuracy: 17.1846%
# test accuracy: 17.2154%
# test accuracy: 17.2462%
# test accuracy: 17.2535%
# test accuracy: 17.2608%
# test accuracy: 17.2915%
# test accuracy: 17.2753%
# test accuracy: 17.2825%
# test accuracy: 17.2664%
# test accuracy: 17.2502%
# test accuracy: 17.2575%
# test accuracy: 17.2647%
# test accuracy: 17.2486%
# test accuracy: 17.2558%
# test accuracy: 17.2398%
# test accuracy: 17.2238%
# test accuracy: 17.2078%
# test accuracy: 17.2382%
# test accuracy: 17.2222%
# test accuracy: 17.2525%
# test accuracy: 17.2597%
# test accuracy: 17.2669%
# test accuracy: 17.2509%
# test accuracy: 17.2581%
# test accuracy: 17.2652%
# test accuracy: 17.2953%
# test accuracy: 17.2794%
# test accuracy: 17.2865%
# test accuracy: 17.2936%
# test accuracy: 17.2777%
# test accuracy: 17.2619%
# test accuracy: 17.2690%
# test accuracy: 17.2761%
# test accuracy: 17.2603%
# test accuracy: 17.2901%
# test accuracy: 17.2744%
# test accuracy: 17.2814%
# test accuracy: 17.3339%
# test accuracy: 17.3409%
# test accuracy: 17.3479%
# test accuracy: 17.3775%
# test accuracy: 17.3844%
# test accuracy: 17.3913%
# test accuracy: 17.3756%
# test accuracy: 17.3825%
# test accuracy: 17.3668%
# test accuracy: 17.3962%
# test accuracy: 17.4482%
# test accuracy: 17.4550%
# test accuracy: 17.4617%
# test accuracy: 17.4460%
# test accuracy: 17.4753%
# test accuracy: 17.4596%
# test accuracy: 17.4439%
# test accuracy: 17.4507%
# test accuracy: 17.4351%
# test accuracy: 17.4419%
# test accuracy: 17.4263%
# test accuracy: 17.4330%
# test accuracy: 17.4398%
# test accuracy: 17.4242%
# test accuracy: 17.4310%
# test accuracy: 17.4377%
# test accuracy: 17.4222%
# test accuracy: 17.4067%
# test accuracy: 17.4357%
# test accuracy: 17.4202%
# test accuracy: 17.4048%
# test accuracy: 17.3894%
# test accuracy: 17.3740%
# test accuracy: 17.3807%
# test accuracy: 17.3875%
# test accuracy: 17.3721%
# test accuracy: 17.3789%
# test accuracy: 17.3636%
# test accuracy: 17.3483%
# test accuracy: 17.3550%
# test accuracy: 17.3398%
# test accuracy: 17.3246%
# test accuracy: 17.3094%
# test accuracy: 17.3380%
# test accuracy: 17.3447%
# test accuracy: 17.3514%
# test accuracy: 17.3581%
# test accuracy: 17.3429%
# test accuracy: 17.3278%
# test accuracy: 17.3127%
# test accuracy: 17.3412%
# test accuracy: 17.3261%
# test accuracy: 17.3328%
# test accuracy: 17.3611%
# test accuracy: 17.3461%
# test accuracy: 17.3744%
# test accuracy: 17.3810%
# test accuracy: 17.3659%
# test accuracy: 17.3509%
# test accuracy: 17.3359%
# test accuracy: 17.3210%
# test accuracy: 17.3491%
# test accuracy: 17.3557%
# test accuracy: 17.3408%
# test accuracy: 17.3474%
# test accuracy: 17.3754%
# test accuracy: 17.3605%
# test accuracy: 17.3671%
# test accuracy: 17.3950%
# test accuracy: 17.4015%
# test accuracy: 17.3867%
# test accuracy: 17.3718%
# test accuracy: 17.3570%
# test accuracy: 17.3422%
# test accuracy: 17.3487%
# test accuracy: 17.3339%
# test accuracy: 17.3191%
# test accuracy: 17.3044%
# test accuracy: 17.3110%
# test accuracy: 17.3175%
# test accuracy: 17.3240%
# test accuracy: 17.3305%
# test accuracy: 17.3582%
# test accuracy: 17.3646%
# test accuracy: 17.3711%
# test accuracy: 17.3564%
# test accuracy: 17.3418%
# test accuracy: 17.3272%
# test accuracy: 17.3126%
# test accuracy: 17.3401%
# test accuracy: 17.3465%
# test accuracy: 17.3319%
# test accuracy: 17.3384%
# test accuracy: 17.3448%
# test accuracy: 17.3512%
# test accuracy: 17.3576%
# test accuracy: 17.3431%
# test accuracy: 17.3495%
# test accuracy: 17.3350%
# test accuracy: 17.3205%
# test accuracy: 17.3061%
# test accuracy: 17.3333%
# test accuracy: 17.3397%
# test accuracy: 17.3461%
# test accuracy: 17.3525%
# test accuracy: 17.3380%
# test accuracy: 17.3444%
# test accuracy: 17.3300%
# test accuracy: 17.3364%
# test accuracy: 17.3220%
# test accuracy: 17.3077%
# test accuracy: 17.2934%
# test accuracy: 17.3410%
# test accuracy: 17.3267%
# test accuracy: 17.3331%
# test accuracy: 17.3394%
# test accuracy: 17.3251%
# test accuracy: 17.3314%
# test accuracy: 17.3377%
# test accuracy: 17.3440%
# test accuracy: 17.3298%
# test accuracy: 17.3156%
# test accuracy: 17.3219%
# test accuracy: 17.3282%
# test accuracy: 17.3344%
# test accuracy: 17.3203%
# test accuracy: 17.3265%
# test accuracy: 17.3124%
# test accuracy: 17.3187%
# test accuracy: 17.3249%
# test accuracy: 17.3312%
# test accuracy: 17.3171%
# test accuracy: 17.3436%
# test accuracy: 17.3295%
# test accuracy: 17.3155%
# test accuracy: 17.3217%
# test accuracy: 17.3279%
# test accuracy: 17.3139%
# test accuracy: 17.3201%
# test accuracy: 17.3061%
# test accuracy: 17.2922%
# test accuracy: 17.2782%
# test accuracy: 17.2643%
# test accuracy: 17.2504%
# test accuracy: 17.2365%
# test accuracy: 17.2227%
# test accuracy: 17.2289%
# test accuracy: 17.2151%
# test accuracy: 17.2013%
# test accuracy: 17.1875%
# test accuracy: 17.1737%
# test accuracy: 17.1800%
# test accuracy: 17.1863%
# test accuracy: 17.2125%
# test accuracy: 17.1987%
# test accuracy: 17.1850%
# test accuracy: 17.1912%
# test accuracy: 17.1775%
# test accuracy: 17.1838%
# test accuracy: 17.2099%
# test accuracy: 17.2160%
# test accuracy: 17.2222%
# test accuracy: 17.2086%
# test accuracy: 17.2147%
# test accuracy: 17.2011%
# test accuracy: 17.1875%
# test accuracy: 17.1937%
# test accuracy: 17.1998%
# test accuracy: 17.2060%
# test accuracy: 17.2121%
# test accuracy: 17.2183%
# test accuracy: 17.2638%
# test accuracy: 17.2895%
# test accuracy: 17.2759%
# test accuracy: 17.2624%
# test accuracy: 17.2488%
# test accuracy: 17.2353%
# test accuracy: 17.2218%
# test accuracy: 17.2083%
# test accuracy: 17.1948%
# test accuracy: 17.2009%
# test accuracy: 17.2070%
# test accuracy: 17.1936%
# test accuracy: 17.1802%
# test accuracy: 17.1668%
# test accuracy: 17.2118%
# test accuracy: 17.1984%
# test accuracy: 17.2045%
# test accuracy: 17.1911%
# test accuracy: 17.1972%
# test accuracy: 17.2033%
# test accuracy: 17.2093%
# test accuracy: 17.2153%
# test accuracy: 17.2020%
# test accuracy: 17.2274%
# test accuracy: 17.2334%
# test accuracy: 17.2587%
# test accuracy: 17.2647%
# test accuracy: 17.2706%
# test accuracy: 17.2766%
# test accuracy: 17.2825%
# test accuracy: 17.2885%
# test accuracy: 17.2752%
# test accuracy: 17.2619%
# test accuracy: 17.2678%
# test accuracy: 17.2546%
# test accuracy: 17.2414%
# test accuracy: 17.2473%
# test accuracy: 17.2533%
# test accuracy: 17.2401%
# test accuracy: 17.2269%
# test accuracy: 17.2328%
# test accuracy: 17.2387%
# test accuracy: 17.2637%
# test accuracy: 17.2506%
# test accuracy: 17.2374%
# test accuracy: 17.2243%
# test accuracy: 17.2112%
# test accuracy: 17.2172%
# test accuracy: 17.2041%
# test accuracy: 17.1911%
# test accuracy: 17.2159%
# test accuracy: 17.2218%
# test accuracy: 17.2277%
# test accuracy: 17.2336%
# test accuracy: 17.2394%
# test accuracy: 17.2453%
# test accuracy: 17.2511%
# test accuracy: 17.2758%
# test accuracy: 17.2628%
# test accuracy: 17.2686%
# test accuracy: 17.2556%
# test accuracy: 17.2427%
# test accuracy: 17.2673%
# test accuracy: 17.2731%
# test accuracy: 17.2976%
# test accuracy: 17.3034%
# test accuracy: 17.2904%
# test accuracy: 17.2775%
# test accuracy: 17.3019%
# test accuracy: 17.2890%
# test accuracy: 17.2761%
# test accuracy: 17.2632%
# test accuracy: 17.2504%
# test accuracy: 17.2375%
# test accuracy: 17.2433%
# test accuracy: 17.2491%
# test accuracy: 17.2363%
# test accuracy: 17.2420%
# test accuracy: 17.2663%
# test accuracy: 17.2535%
# test accuracy: 17.2407%
# test accuracy: 17.2465%
# test accuracy: 17.2337%
# test accuracy: 17.2210%
# test accuracy: 17.2083%
# test accuracy: 17.2140%
# test accuracy: 17.2198%
# test accuracy: 17.2071%
# test accuracy: 17.1944%
# test accuracy: 17.1818%
# test accuracy: 17.1691%
# test accuracy: 17.1932%
# test accuracy: 17.1990%
# test accuracy: 17.2230%
# test accuracy: 17.2287%
# test accuracy: 17.2161%
# test accuracy: 17.2218%
# test accuracy: 17.2641%
# test accuracy: 17.2697%
# test accuracy: 17.2754%
# test accuracy: 17.2810%
# test accuracy: 17.2684%
# test accuracy: 17.2741%
# test accuracy: 17.2797%
# test accuracy: 17.2853%
# test accuracy: 17.2727%
# test accuracy: 17.2602%
# test accuracy: 17.2476%
# test accuracy: 17.2533%
# test accuracy: 17.2589%
# test accuracy: 17.2645%
# test accuracy: 17.2701%
# test accuracy: 17.2757%
# test accuracy: 17.2813%
# test accuracy: 17.2868%
# test accuracy: 17.2744%
# test accuracy: 17.2619%
# test accuracy: 17.2495%
# test accuracy: 17.2370%
# test accuracy: 17.2246%
# test accuracy: 17.2122%
# test accuracy: 17.1999%
# test accuracy: 17.2055%
# test accuracy: 17.1931%
# test accuracy: 17.1987%
# test accuracy: 17.2043%
# test accuracy: 17.2099%
# test accuracy: 17.2155%
# test accuracy: 17.2210%
# test accuracy: 17.2266%
# test accuracy: 17.2321%
# test accuracy: 17.2377%
# test accuracy: 17.2254%
# test accuracy: 17.2488%
# test accuracy: 17.2365%
# test accuracy: 17.2598%
# test accuracy: 17.2475%
# test accuracy: 17.2353%
# test accuracy: 17.2230%
# test accuracy: 17.2285%
# test accuracy: 17.2340%
# test accuracy: 17.2218%
# test accuracy: 17.2273%
# test accuracy: 17.2328%
# test accuracy: 17.2207%
# test accuracy: 17.2261%
# test accuracy: 17.2140%
# test accuracy: 17.2195%
# test accuracy: 17.2426%
# test accuracy: 17.2304%
# test accuracy: 17.2183%
# test accuracy: 17.2238%
# test accuracy: 17.2293%
# test accuracy: 17.2171%
# test accuracy: 17.2051%
# test accuracy: 17.1930%
# test accuracy: 17.1985%
# test accuracy: 17.2039%
# test accuracy: 17.2269%
# test accuracy: 17.2323%
# test accuracy: 17.2378%
# test accuracy: 17.2432%
# test accuracy: 17.2486%
# test accuracy: 17.2366%
# test accuracy: 17.2420%
# test accuracy: 17.2474%
# test accuracy: 17.2354%
# test accuracy: 17.2408%
# test accuracy: 17.2462%
# test accuracy: 17.2516%
# test accuracy: 17.2743%
# test accuracy: 17.2970%
# test accuracy: 17.3024%
# test accuracy: 17.3250%
# test accuracy: 17.3130%
# test accuracy: 17.3183%
# test accuracy: 17.3064%
# test accuracy: 17.2944%
# test accuracy: 17.3170%
# test accuracy: 17.3223%
# test accuracy: 17.3103%
# test accuracy: 17.3156%
# test accuracy: 17.3037%
# test accuracy: 17.3090%
# test accuracy: 17.2971%
# test accuracy: 17.2852%
# test accuracy: 17.2905%
# test accuracy: 17.2787%
# test accuracy: 17.3011%
# test accuracy: 17.3064%
# test accuracy: 17.3116%
# test accuracy: 17.3169%
# test accuracy: 17.3222%
# test accuracy: 17.3103%
# test accuracy: 17.3156%
# test accuracy: 17.3208%
# test accuracy: 17.3431%
# test accuracy: 17.3313%
# test accuracy: 17.3195%
# test accuracy: 17.3247%
# test accuracy: 17.3299%
# test accuracy: 17.3182%
# test accuracy: 17.3234%
# test accuracy: 17.3286%
# test accuracy: 17.3338%
# test accuracy: 17.3220%
# test accuracy: 17.3103%
# test accuracy: 17.2986%
# test accuracy: 17.2869%
# test accuracy: 17.2752%
# test accuracy: 17.2804%
# test accuracy: 17.2856%
# test accuracy: 17.2740%
# test accuracy: 17.2623%
# test accuracy: 17.2507%
# test accuracy: 17.2727%
# test accuracy: 17.2779%
# test accuracy: 17.2831%
# test accuracy: 17.2883%
# test accuracy: 17.2767%
# test accuracy: 17.2651%
# test accuracy: 17.2703%
# test accuracy: 17.2587%
# test accuracy: 17.2639%
# test accuracy: 17.2858%
# test accuracy: 17.2742%
# test accuracy: 17.2794%
# test accuracy: 17.2846%
# test accuracy: 17.2897%
# test accuracy: 17.2782%
# test accuracy: 17.2833%
# test accuracy: 17.2718%
# test accuracy: 17.2603%
# test accuracy: 17.2488%
# test accuracy: 17.2374%
# test accuracy: 17.2259%
# test accuracy: 17.2145%
# test accuracy: 17.2196%
# test accuracy: 17.2082%
# test accuracy: 17.1968%
# test accuracy: 17.1854%
# test accuracy: 17.1906%
# test accuracy: 17.1958%
# test accuracy: 17.1844%
# test accuracy: 17.1731%
# test accuracy: 17.1617%
# test accuracy: 17.1504%
# test accuracy: 17.1556%
# test accuracy: 17.1607%
# test accuracy: 17.1659%
# test accuracy: 17.2039%
# test accuracy: 17.2091%
# test accuracy: 17.2142%
# test accuracy: 17.2193%
# test accuracy: 17.2080%
# test accuracy: 17.2295%
# test accuracy: 17.2182%
# test accuracy: 17.2069%
# test accuracy: 17.2120%
# test accuracy: 17.2008%
# test accuracy: 17.2059%
# test accuracy: 17.1946%
# test accuracy: 17.1997%
# test accuracy: 17.1885%
# test accuracy: 17.2099%
# test accuracy: 17.2150%
# test accuracy: 17.2363%
# test accuracy: 17.2414%
# test accuracy: 17.2302%
# test accuracy: 17.2352%
# test accuracy: 17.2240%
# test accuracy: 17.2128%
# test accuracy: 17.2017%
# test accuracy: 17.1905%
# test accuracy: 17.1794%
# test accuracy: 17.2168%
# test accuracy: 17.2057%
# test accuracy: 17.1946%
# test accuracy: 17.1835%
# test accuracy: 17.1885%
# test accuracy: 17.1774%
# test accuracy: 17.1825%
# test accuracy: 17.1714%
# test accuracy: 17.1603%
# test accuracy: 17.1654%
# test accuracy: 17.1704%
# test accuracy: 17.1754%
# test accuracy: 17.1805%
# test accuracy: 17.1694%
# test accuracy: 17.1584%
# test accuracy: 17.1474%
# test accuracy: 17.1525%
# test accuracy: 17.1575%
# test accuracy: 17.1625%
# test accuracy: 17.1675%
# test accuracy: 17.1565%
# test accuracy: 17.1456%
# test accuracy: 17.1506%
# test accuracy: 17.1556%
# test accuracy: 17.1765%
# test accuracy: 17.2134%
# test accuracy: 17.2183%
# test accuracy: 17.2233%
# test accuracy: 17.2282%
# test accuracy: 17.2173%
# test accuracy: 17.2222%
# test accuracy: 17.2430%
# test accuracy: 17.2479%
# test accuracy: 17.2529%
# test accuracy: 17.2419%
# test accuracy: 17.2468%
# test accuracy: 17.2517%
# test accuracy: 17.2724%
# test accuracy: 17.2615%
# test accuracy: 17.2506%
# test accuracy: 17.2555%
# test accuracy: 17.2446%
# test accuracy: 17.2338%
# test accuracy: 17.2229%
# test accuracy: 17.2435%
# test accuracy: 17.2484%
# test accuracy: 17.2533%
# test accuracy: 17.2425%
# test accuracy: 17.2630%
# test accuracy: 17.2522%
# test accuracy: 17.2727%
# test accuracy: 17.2932%
# test accuracy: 17.2824%
# test accuracy: 17.2872%
# test accuracy: 17.2764%
# test accuracy: 17.2656%
# test accuracy: 17.2705%
# test accuracy: 17.2909%
# test accuracy: 17.2801%
# test accuracy: 17.2693%
# test accuracy: 17.2741%
# test accuracy: 17.2634%
# test accuracy: 17.2526%
# test accuracy: 17.2575%
# test accuracy: 17.2623%
# test accuracy: 17.2516%
# test accuracy: 17.2408%
# test accuracy: 17.2301%
# test accuracy: 17.2505%
# test accuracy: 17.2553%
# test accuracy: 17.2446%
# test accuracy: 17.2339%
# test accuracy: 17.2542%
# test accuracy: 17.2435%
# test accuracy: 17.2329%
# test accuracy: 17.2531%
# test accuracy: 17.2733%
# test accuracy: 17.2626%
# test accuracy: 17.2982%
# test accuracy: 17.2876%
# test accuracy: 17.2769%
# test accuracy: 17.2817%
# test accuracy: 17.2864%
# test accuracy: 17.2758%
# test accuracy: 17.2652%
# test accuracy: 17.2699%
# test accuracy: 17.2594%
# test accuracy: 17.2641%
# test accuracy: 17.2535%
# test accuracy: 17.2430%
# test accuracy: 17.2324%
# test accuracy: 17.2219%
# test accuracy: 17.2266%
# test accuracy: 17.2466%
# test accuracy: 17.2361%
# test accuracy: 17.2256%
# test accuracy: 17.2303%
# test accuracy: 17.2199%
# test accuracy: 17.2246%
# test accuracy: 17.2445%
# test accuracy: 17.2492%
# test accuracy: 17.2539%
# test accuracy: 17.2435%
# test accuracy: 17.2482%
# test accuracy: 17.2529%
# test accuracy: 17.2424%
# test accuracy: 17.2320%
# test accuracy: 17.2367%
# test accuracy: 17.2263%
# test accuracy: 17.2158%
# test accuracy: 17.2054%
# test accuracy: 17.1950%
# test accuracy: 17.1998%
# test accuracy: 17.2045%
# test accuracy: 17.1941%
# test accuracy: 17.1988%
# test accuracy: 17.1884%
# test accuracy: 17.1781%
# test accuracy: 17.1678%
# test accuracy: 17.1725%
# test accuracy: 17.1772%
# test accuracy: 17.1669%
# test accuracy: 17.1716%
# test accuracy: 17.1613%
# test accuracy: 17.1660%
# test accuracy: 17.1707%
# test accuracy: 17.1604%
# test accuracy: 17.1501%
# test accuracy: 17.1548%
# test accuracy: 17.1446%
# test accuracy: 17.1343%
# test accuracy: 17.1539%
# test accuracy: 17.1586%
# test accuracy: 17.1633%
# test accuracy: 17.1531%
# test accuracy: 17.1577%
# test accuracy: 17.1624%
# test accuracy: 17.1522%
# test accuracy: 17.1420%
# test accuracy: 17.1467%
# test accuracy: 17.1365%
# test accuracy: 17.1263%
# test accuracy: 17.1162%
# test accuracy: 17.1209%
# test accuracy: 17.1107%
# test accuracy: 17.1154%
# test accuracy: 17.1200%
# test accuracy: 17.1099%
# test accuracy: 17.1146%
# test accuracy: 17.1045%
# test accuracy: 17.0944%
# test accuracy: 17.0843%
# test accuracy: 17.0890%
# test accuracy: 17.0936%
# test accuracy: 17.0836%
# test accuracy: 17.0735%
# test accuracy: 17.0782%
# test accuracy: 17.0682%
# test accuracy: 17.0728%
# test accuracy: 17.0628%
# test accuracy: 17.0528%
# test accuracy: 17.0574%
# test accuracy: 17.0621%
# test accuracy: 17.0521%
# test accuracy: 17.0568%
# test accuracy: 17.0760%
# test accuracy: 17.0660%
# test accuracy: 17.0561%
# test accuracy: 17.0461%
# test accuracy: 17.0508%
# test accuracy: 17.0408%
# test accuracy: 17.0600%
# test accuracy: 17.0646%
# test accuracy: 17.0693%
# test accuracy: 17.1030%
# test accuracy: 17.1076%
# test accuracy: 17.1121%
# test accuracy: 17.1167%
# test accuracy: 17.1068%
# test accuracy: 17.1114%
# test accuracy: 17.1159%
# test accuracy: 17.1060%
# test accuracy: 17.1106%
# test accuracy: 17.1152%
# test accuracy: 17.1053%
# test accuracy: 17.0954%
# test accuracy: 17.1144%
# test accuracy: 17.1045%
# test accuracy: 17.1235%
# test accuracy: 17.1136%
# test accuracy: 17.1037%
# test accuracy: 17.1083%
# test accuracy: 17.1128%
# test accuracy: 17.1174%
# test accuracy: 17.1075%
# test accuracy: 17.1121%
# test accuracy: 17.1166%
# test accuracy: 17.1211%
# test accuracy: 17.1113%
# test accuracy: 17.1158%
# test accuracy: 17.1203%
# test accuracy: 17.1392%
# test accuracy: 17.1294%
# test accuracy: 17.1339%
# test accuracy: 17.1527%
# test accuracy: 17.1714%
# test accuracy: 17.1616%
# test accuracy: 17.1518%
# test accuracy: 17.1706%
# test accuracy: 17.1893%
# test accuracy: 17.2222%
# test accuracy: 17.2267%
# test accuracy: 17.2311%
# test accuracy: 17.2497%
# test accuracy: 17.2541%
# test accuracy: 17.2585%
# test accuracy: 17.2629%
# test accuracy: 17.2673%
# test accuracy: 17.2575%
# test accuracy: 17.2477%
# test accuracy: 17.2380%
# test accuracy: 17.2282%
# test accuracy: 17.2467%
# test accuracy: 17.2511%
# test accuracy: 17.2555%
# test accuracy: 17.2458%
# test accuracy: 17.2501%
# test accuracy: 17.2404%
# test accuracy: 17.2307%
# test accuracy: 17.2351%
# test accuracy: 17.2535%
# test accuracy: 17.2438%
# test accuracy: 17.2341%
# test accuracy: 17.2525%
# test accuracy: 17.2569%
# test accuracy: 17.2472%
# test accuracy: 17.2515%
# test accuracy: 17.2419%
# test accuracy: 17.2462%
# test accuracy: 17.2365%
# test accuracy: 17.2269%
# test accuracy: 17.2452%
# test accuracy: 17.2356%
# test accuracy: 17.2260%
# test accuracy: 17.2303%
# test accuracy: 17.2486%
# test accuracy: 17.2529%
# test accuracy: 17.2573%
# test accuracy: 17.2616%
# test accuracy: 17.2659%
# test accuracy: 17.2841%
# test accuracy: 17.2745%
# test accuracy: 17.2788%
# test accuracy: 17.2970%
# test accuracy: 17.3152%
# test accuracy: 17.3333%
# test accuracy: 17.3237%
# test accuracy: 17.3280%
# test accuracy: 17.3322%
# test accuracy: 17.3503%
# test accuracy: 17.3684%
# test accuracy: 17.3865%
# test accuracy: 17.3769%
# test accuracy: 17.3673%
# test accuracy: 17.3853%
# test accuracy: 17.3757%
# test accuracy: 17.3661%
# test accuracy: 17.3565%
# test accuracy: 17.3607%
# test accuracy: 17.3512%
# test accuracy: 17.3554%
# test accuracy: 17.3596%
# test accuracy: 17.3500%
# test accuracy: 17.3542%
# test accuracy: 17.3722%
# test accuracy: 17.3626%
# test accuracy: 17.3668%
# test accuracy: 17.3710%
# test accuracy: 17.3889%
# test accuracy: 17.3931%
# test accuracy: 17.3836%
# test accuracy: 17.3740%
# test accuracy: 17.3645%
# test accuracy: 17.3824%
# test accuracy: 17.4139%
# test accuracy: 17.4044%
# test accuracy: 17.4222%
# test accuracy: 17.4127%
# test accuracy: 17.4168%
# test accuracy: 17.4073%
# test accuracy: 17.4114%
# test accuracy: 17.4020%
# test accuracy: 17.3925%
# test accuracy: 17.3830%
# test accuracy: 17.3736%
# test accuracy: 17.3641%
# test accuracy: 17.3683%
# test accuracy: 17.3860%
# test accuracy: 17.4037%
# test accuracy: 17.3943%
# test accuracy: 17.3848%
# test accuracy: 17.3889%
# test accuracy: 17.3795%
# test accuracy: 17.3972%
# test accuracy: 17.3878%
# test accuracy: 17.3784%
# test accuracy: 17.3825%
# test accuracy: 17.4001%
# test accuracy: 17.4042%
# test accuracy: 17.4083%
# test accuracy: 17.3989%
# test accuracy: 17.4165%
# test accuracy: 17.4071%
# test accuracy: 17.3977%
# test accuracy: 17.4153%
# test accuracy: 17.4059%
# test accuracy: 17.3966%
# test accuracy: 17.4006%
# test accuracy: 17.3913%
# test accuracy: 17.3820%
# test accuracy: 17.3861%
# test accuracy: 17.3767%
# test accuracy: 17.3744%

# %%
print(model)
# Out:
# ViT(
#   (to_patch_embedding): Sequential(
#     (0): Rearrange('b c (h p1) (w p2) -> b (h w) (p1 p2 c)', p1=32, p2=32)
#     (1): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#     (2): Linear(in_features=3072, out_features=1024, bias=True)
#     (3): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (transformer): Transformer(
#     (layers): ModuleList(
#       (0-5): 6 x ModuleList(
#         (0): PreNorm(
#           (norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fn): Attention(
#             (attend): Softmax(dim=-1)
#             (dropout): Dropout(p=0.1, inplace=False)
#             (to_qkv): Linear(in_features=1024, out_features=1536, bias=False)
#             (to_out): Sequential(
#               (0): Linear(in_features=512, out_features=1024, bias=True)
#               (1): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (1): PreNorm(
#           (norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fn): FeedForward(
#             (net): Sequential(
#               (0): Linear(in_features=1024, out_features=2048, bias=True)
#               (1): GELU(approximate='none')
#               (2): Dropout(p=0.1, inplace=False)
#               (3): Linear(in_features=2048, out_features=1024, bias=True)
#               (4): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#     )
#   )
#   (to_latent): Identity()
#   (mlp_head): Sequential(
#     (0): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=1024, out_features=50, bias=True)
#   )
# )
