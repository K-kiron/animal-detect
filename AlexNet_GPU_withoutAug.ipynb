# %% [markdown]
# Lien de téléchargement des données: https://cvml.ista.ac.at/AwA2/
#
# 13GB file : https://cvml.ista.ac.at/AwA2/AwA2-data.zip

# %%
# !pip install wandb -qU

# %%
# Log in to your W&B account
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: yanzhang7271 (-yanzhang). Use `wandb login --relogin` to force relogin
# True

# %%
# wandb: Currently logged in as: yanzhang7271 (-yanzhang). Use `wandb login --relogin` to force relogin
# pip install wandb

# %%
import sys
import cv2 # Pour utiliser open_cv, il faut la version de python est 3.7
import os
import csv

import numpy as np 
import pandas as pd 
import math

import torch 
from torch.utils.data import Dataset, DataLoader
import torchvision 
from torchvision.io import read_image
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torch.optim as optim
from torch.utils.data.sampler import SubsetRandomSampler


import matplotlib.pyplot as plt

np.random.seed(0)

# %%
import wandb

# %%
# Constant. Should be the path to the folder named JPEGImages, containing the 33K images in its subfolders.
JPEGIMAGES_FOLDER_PATH = "C:/Users/1/Desktop/data_ift3710/Animals_with_Attributes2/JPEGImages/"
path_project = "C:/Users/1/Desktop/data_ift3710/Animals_with_Attributes2/"

# %%
labels_dirs = os.listdir(JPEGIMAGES_FOLDER_PATH)
print(labels_dirs)
len(labels_dirs) # 50 labels / subdirectories
# Out:
# ['antelope', 'bat', 'beaver', 'blue+whale', 'bobcat', 'buffalo', 'chihuahua', 'chimpanzee', 'collie', 'cow', 'dalmatian', 'deer', 'dolphin', 'elephant', 'fox', 'german+shepherd', 'giant+panda', 'giraffe', 'gorilla', 'grizzly+bear', 'hamster', 'hippopotamus', 'horse', 'humpback+whale', 'killer+whale', 'leopard', 'lion', 'mole', 'moose', 'mouse', 'otter', 'ox', 'persian+cat', 'pig', 'polar+bear', 'rabbit', 'raccoon', 'rat', 'rhinoceros', 'seal', 'sheep', 'siamese+cat', 'skunk', 'spider+monkey', 'squirrel', 'tiger', 'walrus', 'weasel', 'wolf', 'zebra']
# 50

# %%
def get_num_label(label):
    return labels_dirs.index(labels_dirs)

# %% [markdown]
# # Note : Some labels have a low number of images.
#
# ## Possible solutions to explore :
#     Data augmentation : creating new training data by applying random transformations to existing images, such as rotating, cropping, or flipping them.

# %%
def find_num_images_per_label(img_dir = JPEGIMAGES_FOLDER_PATH): 
    """ 
    USEFUL FOR SAMPLING.
    Return a dict with keys as the 50 labels, and values being the number of images in each subdirectory corresponding to label
    and a second dict with the relative numbers (proportion) for every label compared to the total number of images (useful for sampling)"""
    labels_dirs = os.listdir(img_dir)
    num_images_per_label = dict.fromkeys(labels_dirs)
    proportions_images_per_label = dict.fromkeys(labels_dirs)
    total_num_images = 0

    # Update absolute number of images per label
    for i, label in enumerate(labels_dirs) : 
        specific_label_path = os.path.join(img_dir, labels_dirs[i])
        num_images_label = len(os.listdir(specific_label_path))
        total_num_images += num_images_label
        num_images_per_label[label] = num_images_label

    # Update relative number of images per label (proportion)
    for i, label in enumerate(labels_dirs) : 
        num_images_label = num_images_per_label[label]
        proportion_label = round(num_images_label / total_num_images, 4)
        proportions_images_per_label[label] = proportion_label

    return num_images_per_label, proportions_images_per_label

num_images_per_label, proportions_images_per_label = find_num_images_per_label()

# %%
ANNOTATIONS_FILENAME = 'annotations.csv'

def create_annotations_csv_file(annotations_filename = ANNOTATIONS_FILENAME, img_dir = JPEGIMAGES_FOLDER_PATH) : 
    """ 
    Create a csv annotations_file, annotations.csv, with two columns, in the format : 
                        path/to/image, label
    
    The annotation csv is necessary for DataLoader.
    """

    labels_dirs:list = os.listdir(img_dir)
   
    if os.path.exists(annotations_filename):
        os.remove(annotations_filename)
        print(f'Deleted existent {ANNOTATIONS_FILENAME} file.\n ---------------------------')
    
    with open(annotations_filename, 'w', newline='') as file :
        writer = csv.writer(file, dialect='excel', delimiter=',')

        for i, label in enumerate(labels_dirs) : 

            specific_label_path = os.path.join(img_dir, label)
            images_names = os.listdir(specific_label_path)

            for j, image_name in enumerate(images_names):
                full_path_to_img= os.path.join(specific_label_path, image_name)
                full_path_to_img= os.path.join(label, image_name)

                row = [full_path_to_img, label]
                writer.writerow(row)

    print(f'Sucessfully created {ANNOTATIONS_FILENAME} file.')

#
create_annotations_csv_file()
# Out:
# Deleted existent annotations.csv file.
#  ---------------------------
# Sucessfully created annotations.csv file.

# %%
class AWA2Dataset(Dataset): # Dataset class to serve as input for the DataLoader.
    """ 
    Dataset class to serve as input for the DataLoader.
    Implements all the required methods and more. 
    """

    def __init__(self, annotations_file=ANNOTATIONS_FILENAME, img_dir=JPEGIMAGES_FOLDER_PATH, 
                transform=None, target_transform=None):
        self.img_labels = pd.read_csv(annotations_file)
        self.img_dir = img_dir
        self.transform = transform
        self.target_transform = target_transform

        numbers_infos_dicts: tuple[dict,dict] = find_num_images_per_label(img_dir=JPEGIMAGES_FOLDER_PATH)
        self.num_images_per_label = numbers_infos_dicts[0]
        self.proportions_images_per_label = numbers_infos_dicts[1]

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        # img_path = self.img_labels.iloc[idx, 0]
        label = self.img_labels.iloc[idx, 1]

        image = read_image(img_path)
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %%
dataset = AWA2Dataset()

## TODO : Change transforms. Currently this is not useful.
dataset.transform = transforms.Compose([
                    transforms.ToPILImage(),
                    transforms.Resize((256,256)),
                    transforms.CenterCrop((224,224)),
                    transforms.Grayscale(num_output_channels=3),
                    transforms.ToTensor(), # Already a tensor as implemented in Dataset class with the reaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
                    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
                ])

# Testing. All good
random_index = np.random.randint(0, len(dataset))
image, label = dataset[random_index]

# %%
# Experiment with DataLoader. Everything works good
dataloader = DataLoader(dataset = dataset, batch_size=16, shuffle=True)
dataiter = iter(dataloader)
data = next(dataiter)

images, labels = data

# %% [markdown]
# ###   AlexNet  ###

# %%
AlexNet_model = torch.hub.load('pytorch/vision:v0.6.0', 'alexnet', pretrained=False)

#Model description
AlexNet_model.eval()
# Out:
# Using cache found in C:\Users\1/.cache\torch\hub\pytorch_vision_v0.6.0
# D:\anaconda3\envs\pytorch\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# D:\anaconda3\envs\pytorch\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# ### CUDA ###

# %%
device = torch.device("cuda:0")
device
# Out:
# device(type='cuda', index=0)

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### Question: nombre de noeud ###

# %%
nb_noeud = 4096

# %%
AlexNet_model.classifier[4] = torch.nn.Linear(4096,nb_noeud)
AlexNet_model.classifier[6] = torch.nn.Linear(nb_noeud,50)

# %%
import sys
print(sys.version)
# Out:
# 3.8.16 (default, Mar  2 2023, 03:18:16) [MSC v.1916 64 bit (AMD64)]

# %%
AlexNet_model.to(device)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=50, bias=True)
#   )
# )

# %% [markdown]
# ### Question: check dimension de dataloader   ###

# %% [markdown]
# ###  Split training data and test data ###

# %%
batch_size = 128

# %%
dataloader = DataLoader(dataset = dataset, batch_size=batch_size, shuffle=True)
train_size = int(0.8*len(dataset))
test_size = len(dataset) - train_size

# %%
train_dataset, test_dataset = torch.utils.data.random_split(dataset,[train_size,test_size])

# %%
train_loader = DataLoader(train_dataset, batch_size = batch_size, shuffle=False, num_workers=0)
test_loader = DataLoader(test_dataset, batch_size = batch_size, shuffle=False, num_workers=0)

# %% [markdown]
# ###   transfomer labels  ###

# %%
path_class = path_project +"classes.txt"
class_animal = pd.read_table(path_class,header= None)

# %%
animals = class_animal[1]

# %%
dict_label_animal = {}

# %%
n = 0
for i in range(0,len(animals)):
    dict_label_animal[animals[i]] = n
    n+=1

# %%
def label_to_num(tuple_labels):
    list_labels =[]
    for tuple_label in tuple_labels:
        list_labels.append(dict_label_animal[tuple_label])
    return torch.tensor(list_labels)

# %% [markdown]
# ###   Loss function  ###

# %%
lr = 0.0001

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.Adam(AlexNet_model.parameters(), lr= lr)

# %%
torch.cuda.empty_cache()

# %% [markdown]
# ###  Training  ###

# %%
wandb.init(
    # set the wandb project where this run will be logged
    project="AlexNet",
    
    # track hyperparameters and run metadata
    config={
    "learning_rate": 0.0001,
    "architecture": "AlexNet",
    "dataset": "AWA2",
    "epochs": 20,
    }
)

for epoch in range(20):  # loop over the dataset multiple times
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs = data[0].to(device)
        labels = label_to_num(data[1]).to(device)
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        output = AlexNet_model(inputs)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()

        print('[%d, %5d] loss: %.3f' %
              (epoch + 1, i + 1, running_loss ))
        
        # acc
        print('current batch acc', (labels == output.argmax(dim=1)[0]).int().sum() / labels.size(0))
        
        # log metrics to wandb
        wandb.log({"loss": running_loss, "acc": (labels == output.argmax(dim=1)[0]).int().sum() / labels.size(0)})
        
        running_loss = 0.0

print('Finished Training of AlexNet')
# Out:
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>C:\Users\1\Desktop\data_ift3710\wandb\run-20230406_001433-kfutwg1g</code>
# Syncing run <strong><a href='https://wandb.ai/-yanzhang/AlexNet/runs/kfutwg1g' target="_blank">nemesis-enterprise-22</a></strong> to <a href='https://wandb.ai/-yanzhang/AlexNet' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/-yanzhang/AlexNet' target="_blank">https://wandb.ai/-yanzhang/AlexNet</a>
#  View run at <a href='https://wandb.ai/-yanzhang/AlexNet/runs/kfutwg1g' target="_blank">https://wandb.ai/-yanzhang/AlexNet/runs/kfutwg1g</a>
# [1,     1] loss: 3.912
# current batch acc tensor(0., device='cuda:0')
# [1,     2] loss: 3.905
# current batch acc tensor(0.0312, device='cuda:0')
# [1,     3] loss: 3.894
# current batch acc tensor(0.0312, device='cuda:0')
# [1,     4] loss: 3.880
# current batch acc tensor(0.0312, device='cuda:0')
# [1,     5] loss: 3.804
# current batch acc tensor(0.0547, device='cuda:0')
# [1,     6] loss: 3.880
# current batch acc tensor(0.0312, device='cuda:0')
# [1,     7] loss: 3.801
# current batch acc tensor(0.0391, device='cuda:0')
# [1,     8] loss: 3.802
# current batch acc tensor(0.0625, device='cuda:0')
# [1,     9] loss: 3.794
# current batch acc tensor(0.0547, device='cuda:0')
# [1,    10] loss: 3.865
# current batch acc tensor(0.0234, device='cuda:0')
# [1,    11] loss: 3.813
# current batch acc tensor(0.0156, device='cuda:0')
# [1,    12] loss: 3.790
# current batch acc tensor(0.0156, device='cuda:0')
# [1,    13] loss: 3.793
# current batch acc tensor(0.0625, device='cuda:0')
# [1,    14] loss: 3.842
# current batch acc tensor(0.0391, device='cuda:0')
# [1,    15] loss: 3.789
# current batch acc tensor(0.0312, device='cuda:0')
# [1,    16] loss: 3.737
# current batch acc tensor(0.0391, device='cuda:0')
# [1,    17] loss: 3.809
# current batch acc tensor(0.0312, device='cuda:0')
# [1,    18] loss: 3.825
# current batch acc tensor(0.0312, device='cuda:0')
# [1,    19] loss: 3.798
# current batch acc tensor(0.0469, device='cuda:0')
# [1,    20] loss: 3.813
# current batch acc tensor(0.0312, device='cuda:0')
# [1,    21] loss: 3.848
# current batch acc tensor(0.0234, device='cuda:0')
# [1,    22] loss: 3.777
# current batch acc tensor(0.0703, device='cuda:0')
# [1,    23] loss: 3.864
# current batch acc tensor(0.0156, device='cuda:0')
# [1,    24] loss: 3.807
# current batch acc tensor(0.0625, device='cuda:0')
# [1,    25] loss: 3.847
# current batch acc tensor(0.0469, device='cuda:0')
# [1,    26] loss: 3.841
# current batch acc tensor(0.0391, device='cuda:0')
# [1,    27] loss: 3.795
# current batch acc tensor(0.0469, device='cuda:0')
# [1,    28] loss: 3.854
# current batch acc tensor(0.0234, device='cuda:0')
# [1,    29] loss: 3.823
# current batch acc tensor(0.0547, device='cuda:0')
# [1,    30] loss: 3.787
# current batch acc tensor(0.0547, device='cuda:0')
# [1,    31] loss: 3.768
# current batch acc tensor(0.0781, device='cuda:0')
# [1,    32] loss: 3.822
# current batch acc tensor(0.0156, device='cuda:0')
# [1,    33] loss: 3.777
# current batch acc tensor(0.0547, device='cuda:0')
# [1,    34] loss: 3.739
# current batch acc tensor(0.0391, device='cuda:0')
# [1,    35] loss: 3.781
# current batch acc tensor(0.0312, device='cuda:0')
# [1,    36] loss: 3.807
# current batch acc tensor(0.0078, device='cuda:0')
# [1,    37] loss: 3.811
# current batch acc tensor(0.0234, device='cuda:0')
# [1,    38] loss: 3.729
# current batch acc tensor(0.0234, device='cuda:0')
# [1,    39] loss: 3.773
# current batch acc tensor(0.0312, device='cuda:0')
# [1,    40] loss: 3.741
# current batch acc tensor(0.0625, device='cuda:0')
# [1,    41] loss: 3.839
# current batch acc tensor(0.0156, device='cuda:0')
# [1,    42] loss: 3.738
# current batch acc tensor(0.0312, device='cuda:0')
# [1,    43] loss: 3.751
# current batch acc tensor(0.0391, device='cuda:0')
# [1,    44] loss: 3.764
# current batch acc tensor(0.0391, device='cuda:0')
# [1,    45] loss: 3.815
# current batch acc tensor(0.0312, device='cuda:0')
# [1,    46] loss: 3.722
# current batch acc tensor(0.0234, device='cuda:0')
# [1,    47] loss: 3.778
# current batch acc tensor(0.0547, device='cuda:0')
# [1,    48] loss: 3.755
# current batch acc tensor(0.0078, device='cuda:0')
# [1,    49] loss: 3.718
# current batch acc tensor(0.0078, device='cuda:0')
# [1,    50] loss: 3.784
# current batch acc tensor(0.0156, device='cuda:0')
# [1,    51] loss: 3.713
# current batch acc tensor(0.0469, device='cuda:0')
# [1,    52] loss: 3.750
# current batch acc tensor(0.0391, device='cuda:0')
# [1,    53] loss: 3.749
# current batch acc tensor(0.0234, device='cuda:0')
# [1,    54] loss: 3.845
# current batch acc tensor(0.0156, device='cuda:0')
# [1,    55] loss: 3.797
# current batch acc tensor(0.0234, device='cuda:0')
# [1,    56] loss: 3.755
# current batch acc tensor(0.0312, device='cuda:0')
# [1,    57] loss: 3.694
# current batch acc tensor(0.0703, device='cuda:0')
# [1,    58] loss: 3.705
# current batch acc tensor(0.0234, device='cuda:0')
# [1,    59] loss: 3.789
# current batch acc tensor(0.0156, device='cuda:0')
# [1,    60] loss: 3.715
# current batch acc tensor(0.0781, device='cuda:0')
# [1,    61] loss: 3.702
# current batch acc tensor(0.0781, device='cuda:0')
# [1,    62] loss: 3.649
# current batch acc tensor(0.0078, device='cuda:0')
# [1,    63] loss: 3.693
# current batch acc tensor(0.0391, device='cuda:0')
# [1,    64] loss: 3.752
# current batch acc tensor(0.0078, device='cuda:0')
# [1,    65] loss: 3.712
# current batch acc tensor(0.0312, device='cuda:0')
# [1,    66] loss: 3.739
# current batch acc tensor(0.0234, device='cuda:0')
# [1,    67] loss: 3.605
# current batch acc tensor(0.0547, device='cuda:0')
# [1,    68] loss: 3.778
# current batch acc tensor(0.0312, device='cuda:0')
# [1,    69] loss: 3.703
# current batch acc tensor(0.0078, device='cuda:0')
# [1,    70] loss: 3.644
# current batch acc tensor(0.0391, device='cuda:0')
# [1,    71] loss: 3.594
# current batch acc tensor(0.0391, device='cuda:0')
# [1,    72] loss: 3.564
# current batch acc tensor(0.0547, device='cuda:0')
# [1,    73] loss: 3.644
# current batch acc tensor(0.0234, device='cuda:0')
# [1,    74] loss: 3.498
# current batch acc tensor(0.0156, device='cuda:0')
# [1,    75] loss: 3.539
# current batch acc tensor(0.0469, device='cuda:0')
# [1,    76] loss: 3.505
# current batch acc tensor(0.0078, device='cuda:0')
# [1,    77] loss: 3.755
# current batch acc tensor(0.0312, device='cuda:0')
# [1,    78] loss: 3.556
# current batch acc tensor(0.0234, device='cuda:0')
# [1,    79] loss: 3.653
# current batch acc tensor(0.0469, device='cuda:0')
# [1,    80] loss: 3.556
# current batch acc tensor(0.0234, device='cuda:0')
# [1,    81] loss: 3.695
# current batch acc tensor(0.0156, device='cuda:0')
# [1,    82] loss: 3.573
# current batch acc tensor(0.0781, device='cuda:0')
# [1,    83] loss: 3.446
# current batch acc tensor(0.0156, device='cuda:0')
# [1,    84] loss: 3.679
# current batch acc tensor(0.0312, device='cuda:0')
# [1,    85] loss: 3.495
# current batch acc tensor(0.0391, device='cuda:0')
# [1,    86] loss: 3.434
# current batch acc tensor(0.0156, device='cuda:0')
# [1,    87] loss: 3.492
# current batch acc tensor(0.0391, device='cuda:0')
# [1,    88] loss: 3.497
# current batch acc tensor(0.0312, device='cuda:0')
# [1,    89] loss: 3.556
# current batch acc tensor(0.0234, device='cuda:0')
# [1,    90] loss: 3.446
# current batch acc tensor(0.0156, device='cuda:0')
# [1,    91] loss: 3.416
# current batch acc tensor(0.0312, device='cuda:0')
# [1,    92] loss: 3.373
# current batch acc tensor(0.0547, device='cuda:0')
# [1,    93] loss: 3.687
# current batch acc tensor(0.0234, device='cuda:0')
# [1,    94] loss: 3.475
# current batch acc tensor(0.0625, device='cuda:0')
# [1,    95] loss: 3.515
# current batch acc tensor(0.0469, device='cuda:0')
# [1,    96] loss: 3.502
# current batch acc tensor(0.0391, device='cuda:0')
# [1,    97] loss: 3.564
# current batch acc tensor(0.0312, device='cuda:0')
# [1,    98] loss: 3.531
# current batch acc tensor(0.0547, device='cuda:0')
# [1,    99] loss: 3.553
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   100] loss: 3.534
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   101] loss: 3.492
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   102] loss: 3.437
# current batch acc tensor(0.0547, device='cuda:0')
# [1,   103] loss: 3.460
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   104] loss: 3.541
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   105] loss: 3.302
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   106] loss: 3.539
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   107] loss: 3.369
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   108] loss: 3.442
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   109] loss: 3.530
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   110] loss: 3.478
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   111] loss: 3.439
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   112] loss: 3.578
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   113] loss: 3.344
# current batch acc tensor(0.0469, device='cuda:0')
# [1,   114] loss: 3.526
# current batch acc tensor(0., device='cuda:0')
# [1,   115] loss: 3.350
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   116] loss: 3.264
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   117] loss: 3.444
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   118] loss: 3.417
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   119] loss: 3.370
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   120] loss: 3.461
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   121] loss: 3.387
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   122] loss: 3.454
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   123] loss: 3.377
# current batch acc tensor(0.0078, device='cuda:0')
# [1,   124] loss: 3.565
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   125] loss: 3.414
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   126] loss: 3.483
# current batch acc tensor(0.0078, device='cuda:0')
# [1,   127] loss: 3.312
# current batch acc tensor(0.0469, device='cuda:0')
# [1,   128] loss: 3.283
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   129] loss: 3.423
# current batch acc tensor(0.0469, device='cuda:0')
# [1,   130] loss: 3.498
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   131] loss: 3.281
# current batch acc tensor(0.0547, device='cuda:0')
# [1,   132] loss: 3.287
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   133] loss: 3.399
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   134] loss: 3.417
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   135] loss: 3.389
# current batch acc tensor(0.0078, device='cuda:0')
# [1,   136] loss: 3.364
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   137] loss: 3.345
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   138] loss: 3.270
# current batch acc tensor(0.0078, device='cuda:0')
# [1,   139] loss: 3.332
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   140] loss: 3.425
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   141] loss: 3.378
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   142] loss: 3.317
# current batch acc tensor(0.0547, device='cuda:0')
# [1,   143] loss: 3.209
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   144] loss: 3.190
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   145] loss: 3.547
# current batch acc tensor(0.0078, device='cuda:0')
# [1,   146] loss: 3.400
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   147] loss: 3.363
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   148] loss: 3.125
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   149] loss: 3.218
# current batch acc tensor(0.0547, device='cuda:0')
# [1,   150] loss: 3.341
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   151] loss: 3.270
# current batch acc tensor(0.0547, device='cuda:0')
# [1,   152] loss: 3.319
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   153] loss: 3.458
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   154] loss: 3.267
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   155] loss: 3.210
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   156] loss: 3.239
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   157] loss: 3.375
# current batch acc tensor(0.0547, device='cuda:0')
# [1,   158] loss: 3.293
# current batch acc tensor(0.0078, device='cuda:0')
# [1,   159] loss: 3.396
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   160] loss: 3.375
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   161] loss: 3.053
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   162] loss: 3.458
# current batch acc tensor(0.0078, device='cuda:0')
# [1,   163] loss: 3.360
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   164] loss: 3.395
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   165] loss: 3.374
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   166] loss: 3.303
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   167] loss: 3.487
# current batch acc tensor(0.0078, device='cuda:0')
# [1,   168] loss: 3.238
# current batch acc tensor(0.0547, device='cuda:0')
# [1,   169] loss: 3.293
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   170] loss: 3.179
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   171] loss: 3.084
# current batch acc tensor(0.0078, device='cuda:0')
# [1,   172] loss: 3.238
# current batch acc tensor(0.0547, device='cuda:0')
# [1,   173] loss: 3.287
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   174] loss: 3.378
# current batch acc tensor(0.0781, device='cuda:0')
# [1,   175] loss: 3.214
# current batch acc tensor(0.0547, device='cuda:0')
# [1,   176] loss: 3.312
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   177] loss: 3.421
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   178] loss: 3.334
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   179] loss: 3.200
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   180] loss: 2.977
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   181] loss: 3.304
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   182] loss: 3.137
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   183] loss: 3.522
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   184] loss: 3.304
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   185] loss: 3.326
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   186] loss: 3.257
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   187] loss: 3.158
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   188] loss: 3.206
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   189] loss: 3.261
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   190] loss: 3.357
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   191] loss: 3.154
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   192] loss: 3.079
# current batch acc tensor(0.0547, device='cuda:0')
# [1,   193] loss: 3.350
# current batch acc tensor(0., device='cuda:0')
# [1,   194] loss: 3.257
# current batch acc tensor(0.0469, device='cuda:0')
# [1,   195] loss: 3.232
# current batch acc tensor(0.0547, device='cuda:0')
# [1,   196] loss: 3.255
# current batch acc tensor(0.0078, device='cuda:0')
# [1,   197] loss: 3.028
# current batch acc tensor(0.0547, device='cuda:0')
# [1,   198] loss: 3.174
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   199] loss: 3.169
# current batch acc tensor(0.0078, device='cuda:0')
# [1,   200] loss: 3.108
# current batch acc tensor(0.0703, device='cuda:0')
# [1,   201] loss: 3.374
# current batch acc tensor(0.0078, device='cuda:0')
# [1,   202] loss: 3.300
# current batch acc tensor(0., device='cuda:0')
# [1,   203] loss: 3.073
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   204] loss: 3.343
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   205] loss: 3.312
# current batch acc tensor(0.0547, device='cuda:0')
# [1,   206] loss: 3.309
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   207] loss: 3.132
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   208] loss: 3.088
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   209] loss: 3.150
# current batch acc tensor(0.0469, device='cuda:0')
# [1,   210] loss: 3.243
# current batch acc tensor(0.0547, device='cuda:0')
# [1,   211] loss: 3.199
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   212] loss: 3.163
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   213] loss: 3.254
# current batch acc tensor(0.0625, device='cuda:0')
# [1,   214] loss: 3.262
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   215] loss: 3.184
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   216] loss: 3.248
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   217] loss: 3.291
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   218] loss: 3.302
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   219] loss: 3.231
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   220] loss: 3.246
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   221] loss: 3.423
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   222] loss: 3.224
# current batch acc tensor(0.0312, device='cuda:0')
# [1,   223] loss: 3.156
# current batch acc tensor(0.0078, device='cuda:0')
# [1,   224] loss: 3.035
# current batch acc tensor(0.0469, device='cuda:0')
# [1,   225] loss: 3.312
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   226] loss: 3.017
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   227] loss: 3.228
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   228] loss: 3.100
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   229] loss: 3.039
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   230] loss: 3.118
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   231] loss: 3.132
# current batch acc tensor(0.0234, device='cuda:0')
# [1,   232] loss: 3.208
# current batch acc tensor(0.0391, device='cuda:0')
# [1,   233] loss: 3.066
# current batch acc tensor(0.0156, device='cuda:0')
# [1,   234] loss: 3.397
# current batch acc tensor(0.0312, device='cuda:0')
# [2,     1] loss: 3.251
# current batch acc tensor(0.0469, device='cuda:0')
# [2,     2] loss: 2.972
# current batch acc tensor(0.0156, device='cuda:0')
# [2,     3] loss: 3.346
# current batch acc tensor(0.0312, device='cuda:0')
# [2,     4] loss: 3.116
# current batch acc tensor(0.0391, device='cuda:0')
# [2,     5] loss: 3.009
# current batch acc tensor(0.0391, device='cuda:0')
# [2,     6] loss: 3.009
# current batch acc tensor(0.0234, device='cuda:0')
# [2,     7] loss: 3.055
# current batch acc tensor(0.0234, device='cuda:0')
# [2,     8] loss: 3.078
# current batch acc tensor(0.0625, device='cuda:0')
# [2,     9] loss: 3.012
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    10] loss: 3.156
# current batch acc tensor(0.0469, device='cuda:0')
# [2,    11] loss: 3.088
# current batch acc tensor(0.0078, device='cuda:0')
# [2,    12] loss: 2.931
# current batch acc tensor(0.0391, device='cuda:0')
# [2,    13] loss: 2.995
# current batch acc tensor(0., device='cuda:0')
# [2,    14] loss: 3.257
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    15] loss: 2.986
# current batch acc tensor(0.0547, device='cuda:0')
# [2,    16] loss: 2.964
# current batch acc tensor(0.0391, device='cuda:0')
# [2,    17] loss: 2.999
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    18] loss: 3.091
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    19] loss: 2.979
# current batch acc tensor(0.0547, device='cuda:0')
# [2,    20] loss: 2.774
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    21] loss: 3.303
# current batch acc tensor(0.0156, device='cuda:0')
# [2,    22] loss: 3.043
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    23] loss: 3.174
# current batch acc tensor(0.0469, device='cuda:0')
# [2,    24] loss: 2.957
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    25] loss: 3.258
# current batch acc tensor(0.0156, device='cuda:0')
# [2,    26] loss: 3.137
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    27] loss: 3.046
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    28] loss: 3.253
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    29] loss: 3.122
# current batch acc tensor(0.0156, device='cuda:0')
# [2,    30] loss: 3.306
# current batch acc tensor(0.0156, device='cuda:0')
# [2,    31] loss: 3.172
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    32] loss: 3.129
# current batch acc tensor(0.0078, device='cuda:0')
# [2,    33] loss: 2.945
# current batch acc tensor(0.0469, device='cuda:0')
# [2,    34] loss: 3.284
# current batch acc tensor(0.0547, device='cuda:0')
# [2,    35] loss: 2.781
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    36] loss: 2.982
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    37] loss: 2.984
# current batch acc tensor(0.0156, device='cuda:0')
# [2,    38] loss: 2.852
# current batch acc tensor(0.0391, device='cuda:0')
# [2,    39] loss: 2.991
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    40] loss: 2.917
# current batch acc tensor(0.0156, device='cuda:0')
# [2,    41] loss: 2.954
# current batch acc tensor(0.0156, device='cuda:0')
# [2,    42] loss: 2.922
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    43] loss: 3.050
# current batch acc tensor(0.0391, device='cuda:0')
# [2,    44] loss: 3.097
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    45] loss: 3.117
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    46] loss: 3.178
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    47] loss: 3.071
# current batch acc tensor(0.0391, device='cuda:0')
# [2,    48] loss: 2.978
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    49] loss: 3.044
# current batch acc tensor(0.0547, device='cuda:0')
# [2,    50] loss: 3.104
# current batch acc tensor(0.0156, device='cuda:0')
# [2,    51] loss: 3.031
# current batch acc tensor(0.0859, device='cuda:0')
# [2,    52] loss: 3.212
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    53] loss: 2.879
# current batch acc tensor(0.0391, device='cuda:0')
# [2,    54] loss: 3.081
# current batch acc tensor(0.0469, device='cuda:0')
# [2,    55] loss: 3.164
# current batch acc tensor(0.0391, device='cuda:0')
# [2,    56] loss: 3.009
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    57] loss: 2.864
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    58] loss: 2.781
# current batch acc tensor(0.0469, device='cuda:0')
# [2,    59] loss: 2.984
# current batch acc tensor(0.0156, device='cuda:0')
# [2,    60] loss: 2.947
# current batch acc tensor(0.0547, device='cuda:0')
# [2,    61] loss: 2.970
# current batch acc tensor(0.0469, device='cuda:0')
# [2,    62] loss: 2.865
# current batch acc tensor(0.0078, device='cuda:0')
# [2,    63] loss: 2.923
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    64] loss: 2.928
# current batch acc tensor(0.0156, device='cuda:0')
# [2,    65] loss: 2.945
# current batch acc tensor(0.0156, device='cuda:0')
# [2,    66] loss: 3.099
# current batch acc tensor(0.0078, device='cuda:0')
# [2,    67] loss: 3.010
# current batch acc tensor(0.0469, device='cuda:0')
# [2,    68] loss: 3.159
# current batch acc tensor(0.0391, device='cuda:0')
# [2,    69] loss: 3.007
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    70] loss: 2.814
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    71] loss: 2.990
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    72] loss: 2.801
# current batch acc tensor(0.0391, device='cuda:0')
# [2,    73] loss: 2.992
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    74] loss: 2.761
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    75] loss: 3.056
# current batch acc tensor(0.0469, device='cuda:0')
# [2,    76] loss: 2.759
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    77] loss: 2.913
# current batch acc tensor(0.0156, device='cuda:0')
# [2,    78] loss: 2.880
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    79] loss: 3.021
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    80] loss: 2.901
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    81] loss: 2.851
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    82] loss: 2.949
# current batch acc tensor(0.0078, device='cuda:0')
# [2,    83] loss: 2.798
# current batch acc tensor(0.0078, device='cuda:0')
# [2,    84] loss: 2.956
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    85] loss: 2.816
# current batch acc tensor(0.0391, device='cuda:0')
# [2,    86] loss: 2.836
# current batch acc tensor(0.0156, device='cuda:0')
# [2,    87] loss: 2.900
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    88] loss: 2.888
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    89] loss: 2.860
# current batch acc tensor(0.0156, device='cuda:0')
# [2,    90] loss: 2.766
# current batch acc tensor(0.0469, device='cuda:0')
# [2,    91] loss: 2.815
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    92] loss: 2.813
# current batch acc tensor(0.0547, device='cuda:0')
# [2,    93] loss: 2.915
# current batch acc tensor(0.0312, device='cuda:0')
# [2,    94] loss: 2.884
# current batch acc tensor(0.0625, device='cuda:0')
# [2,    95] loss: 2.890
# current batch acc tensor(0.0156, device='cuda:0')
# [2,    96] loss: 2.900
# current batch acc tensor(0.0234, device='cuda:0')
# [2,    97] loss: 2.994
# current batch acc tensor(0.0625, device='cuda:0')
# [2,    98] loss: 2.983
# current batch acc tensor(0.0156, device='cuda:0')
# [2,    99] loss: 3.047
# current batch acc tensor(0.0703, device='cuda:0')
# [2,   100] loss: 2.901
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   101] loss: 2.802
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   102] loss: 2.841
# current batch acc tensor(0.0547, device='cuda:0')
# [2,   103] loss: 2.995
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   104] loss: 2.880
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   105] loss: 2.747
# current batch acc tensor(0.0625, device='cuda:0')
# [2,   106] loss: 3.000
# current batch acc tensor(0.0078, device='cuda:0')
# [2,   107] loss: 2.797
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   108] loss: 3.029
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   109] loss: 3.214
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   110] loss: 3.053
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   111] loss: 2.946
# current batch acc tensor(0.0078, device='cuda:0')
# [2,   112] loss: 2.979
# current batch acc tensor(0.0469, device='cuda:0')
# [2,   113] loss: 2.800
# current batch acc tensor(0.0469, device='cuda:0')
# [2,   114] loss: 3.006
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   115] loss: 2.858
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   116] loss: 2.760
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   117] loss: 2.953
# current batch acc tensor(0.0469, device='cuda:0')
# [2,   118] loss: 2.790
# current batch acc tensor(0.0078, device='cuda:0')
# [2,   119] loss: 2.824
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   120] loss: 2.897
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   121] loss: 2.914
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   122] loss: 2.873
# current batch acc tensor(0.0547, device='cuda:0')
# [2,   123] loss: 2.918
# current batch acc tensor(0.0078, device='cuda:0')
# [2,   124] loss: 2.990
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   125] loss: 2.788
# current batch acc tensor(0.0469, device='cuda:0')
# [2,   126] loss: 2.796
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   127] loss: 2.746
# current batch acc tensor(0.0078, device='cuda:0')
# [2,   128] loss: 2.782
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   129] loss: 2.905
# current batch acc tensor(0.0469, device='cuda:0')
# [2,   130] loss: 3.088
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   131] loss: 2.764
# current batch acc tensor(0.0547, device='cuda:0')
# [2,   132] loss: 2.688
# current batch acc tensor(0.0078, device='cuda:0')
# [2,   133] loss: 2.857
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   134] loss: 2.964
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   135] loss: 2.873
# current batch acc tensor(0.0469, device='cuda:0')
# [2,   136] loss: 2.831
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   137] loss: 2.722
# current batch acc tensor(0.0078, device='cuda:0')
# [2,   138] loss: 2.656
# current batch acc tensor(0.0547, device='cuda:0')
# [2,   139] loss: 2.828
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   140] loss: 2.950
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   141] loss: 2.844
# current batch acc tensor(0.0703, device='cuda:0')
# [2,   142] loss: 2.742
# current batch acc tensor(0.0547, device='cuda:0')
# [2,   143] loss: 2.804
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   144] loss: 2.629
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   145] loss: 2.990
# current batch acc tensor(0.0078, device='cuda:0')
# [2,   146] loss: 2.925
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   147] loss: 2.897
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   148] loss: 2.754
# current batch acc tensor(0.0547, device='cuda:0')
# [2,   149] loss: 2.705
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   150] loss: 3.032
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   151] loss: 2.751
# current batch acc tensor(0.0547, device='cuda:0')
# [2,   152] loss: 2.804
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   153] loss: 2.916
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   154] loss: 2.779
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   155] loss: 2.644
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   156] loss: 2.720
# current batch acc tensor(0.0078, device='cuda:0')
# [2,   157] loss: 2.798
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   158] loss: 2.788
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   159] loss: 2.794
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   160] loss: 3.079
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   161] loss: 2.708
# current batch acc tensor(0.0078, device='cuda:0')
# [2,   162] loss: 2.844
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   163] loss: 2.754
# current batch acc tensor(0.0469, device='cuda:0')
# [2,   164] loss: 2.985
# current batch acc tensor(0.0078, device='cuda:0')
# [2,   165] loss: 2.902
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   166] loss: 2.807
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   167] loss: 3.019
# current batch acc tensor(0.0078, device='cuda:0')
# [2,   168] loss: 2.733
# current batch acc tensor(0.0547, device='cuda:0')
# [2,   169] loss: 2.696
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   170] loss: 2.751
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   171] loss: 2.589
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   172] loss: 2.715
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   173] loss: 2.813
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   174] loss: 2.917
# current batch acc tensor(0.0781, device='cuda:0')
# [2,   175] loss: 2.712
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   176] loss: 2.875
# current batch acc tensor(0.0547, device='cuda:0')
# [2,   177] loss: 2.958
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   178] loss: 2.718
# current batch acc tensor(0.0469, device='cuda:0')
# [2,   179] loss: 2.801
# current batch acc tensor(0.0078, device='cuda:0')
# [2,   180] loss: 2.622
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   181] loss: 2.832
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   182] loss: 2.605
# current batch acc tensor(0.0703, device='cuda:0')
# [2,   183] loss: 2.985
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   184] loss: 2.694
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   185] loss: 2.596
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   186] loss: 2.700
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   187] loss: 2.758
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   188] loss: 2.667
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   189] loss: 2.688
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   190] loss: 2.816
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   191] loss: 2.555
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   192] loss: 2.588
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   193] loss: 2.931
# current batch acc tensor(0., device='cuda:0')
# [2,   194] loss: 2.875
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   195] loss: 2.764
# current batch acc tensor(0.0547, device='cuda:0')
# [2,   196] loss: 2.634
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   197] loss: 2.461
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   198] loss: 2.657
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   199] loss: 2.843
# current batch acc tensor(0.0469, device='cuda:0')
# [2,   200] loss: 2.720
# current batch acc tensor(0.0625, device='cuda:0')
# [2,   201] loss: 2.839
# current batch acc tensor(0.0703, device='cuda:0')
# [2,   202] loss: 2.882
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   203] loss: 2.553
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   204] loss: 2.778
# current batch acc tensor(0.0078, device='cuda:0')
# [2,   205] loss: 2.999
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   206] loss: 2.802
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   207] loss: 2.676
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   208] loss: 2.550
# current batch acc tensor(0.0469, device='cuda:0')
# [2,   209] loss: 2.604
# current batch acc tensor(0.0469, device='cuda:0')
# [2,   210] loss: 2.823
# current batch acc tensor(0.0547, device='cuda:0')
# [2,   211] loss: 2.644
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   212] loss: 2.660
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   213] loss: 2.855
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   214] loss: 2.532
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   215] loss: 2.647
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   216] loss: 2.695
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   217] loss: 2.900
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   218] loss: 2.693
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   219] loss: 2.689
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   220] loss: 2.815
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   221] loss: 2.931
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   222] loss: 2.662
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   223] loss: 2.681
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   224] loss: 2.520
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   225] loss: 2.716
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   226] loss: 2.522
# current batch acc tensor(0.0078, device='cuda:0')
# [2,   227] loss: 2.672
# current batch acc tensor(0.0078, device='cuda:0')
# [2,   228] loss: 2.713
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   229] loss: 2.443
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   230] loss: 2.712
# current batch acc tensor(0.0234, device='cuda:0')
# [2,   231] loss: 2.650
# current batch acc tensor(0.0312, device='cuda:0')
# [2,   232] loss: 2.716
# current batch acc tensor(0.0391, device='cuda:0')
# [2,   233] loss: 2.605
# current batch acc tensor(0.0156, device='cuda:0')
# [2,   234] loss: 2.842
# current batch acc tensor(0., device='cuda:0')
# [3,     1] loss: 2.854
# current batch acc tensor(0.0469, device='cuda:0')
# [3,     2] loss: 2.553
# current batch acc tensor(0.0391, device='cuda:0')
# [3,     3] loss: 2.862
# current batch acc tensor(0.0312, device='cuda:0')
# [3,     4] loss: 2.821
# current batch acc tensor(0.0469, device='cuda:0')
# [3,     5] loss: 2.622
# current batch acc tensor(0.0391, device='cuda:0')
# [3,     6] loss: 2.448
# current batch acc tensor(0.0234, device='cuda:0')
# [3,     7] loss: 2.723
# current batch acc tensor(0.0234, device='cuda:0')
# [3,     8] loss: 2.746
# current batch acc tensor(0.0234, device='cuda:0')
# [3,     9] loss: 2.627
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    10] loss: 2.717
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    11] loss: 2.665
# current batch acc tensor(0.0078, device='cuda:0')
# [3,    12] loss: 2.614
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    13] loss: 2.512
# current batch acc tensor(0., device='cuda:0')
# [3,    14] loss: 2.885
# current batch acc tensor(0.0234, device='cuda:0')
# [3,    15] loss: 2.715
# current batch acc tensor(0.0547, device='cuda:0')
# [3,    16] loss: 2.521
# current batch acc tensor(0.0391, device='cuda:0')
# [3,    17] loss: 2.572
# current batch acc tensor(0.0234, device='cuda:0')
# [3,    18] loss: 2.816
# current batch acc tensor(0.0703, device='cuda:0')
# [3,    19] loss: 2.592
# current batch acc tensor(0.0078, device='cuda:0')
# [3,    20] loss: 2.479
# current batch acc tensor(0.0234, device='cuda:0')
# [3,    21] loss: 2.753
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    22] loss: 2.612
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    23] loss: 2.754
# current batch acc tensor(0.0156, device='cuda:0')
# [3,    24] loss: 2.635
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    25] loss: 2.825
# current batch acc tensor(0.0156, device='cuda:0')
# [3,    26] loss: 2.711
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    27] loss: 2.758
# current batch acc tensor(0.0234, device='cuda:0')
# [3,    28] loss: 2.943
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    29] loss: 2.696
# current batch acc tensor(0.0156, device='cuda:0')
# [3,    30] loss: 2.801
# current batch acc tensor(0.0156, device='cuda:0')
# [3,    31] loss: 2.780
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    32] loss: 2.694
# current batch acc tensor(0.0234, device='cuda:0')
# [3,    33] loss: 2.478
# current batch acc tensor(0.0469, device='cuda:0')
# [3,    34] loss: 2.838
# current batch acc tensor(0.0078, device='cuda:0')
# [3,    35] loss: 2.357
# current batch acc tensor(0.0625, device='cuda:0')
# [3,    36] loss: 2.510
# current batch acc tensor(0.0234, device='cuda:0')
# [3,    37] loss: 2.665
# current batch acc tensor(0.0156, device='cuda:0')
# [3,    38] loss: 2.548
# current batch acc tensor(0.0391, device='cuda:0')
# [3,    39] loss: 2.636
# current batch acc tensor(0.0078, device='cuda:0')
# [3,    40] loss: 2.483
# current batch acc tensor(0.0469, device='cuda:0')
# [3,    41] loss: 2.540
# current batch acc tensor(0.0156, device='cuda:0')
# [3,    42] loss: 2.531
# current batch acc tensor(0.0547, device='cuda:0')
# [3,    43] loss: 2.610
# current batch acc tensor(0.0156, device='cuda:0')
# [3,    44] loss: 2.670
# current batch acc tensor(0.0078, device='cuda:0')
# [3,    45] loss: 2.739
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    46] loss: 2.627
# current batch acc tensor(0., device='cuda:0')
# [3,    47] loss: 2.661
# current batch acc tensor(0.0391, device='cuda:0')
# [3,    48] loss: 2.477
# current batch acc tensor(0.0156, device='cuda:0')
# [3,    49] loss: 2.701
# current batch acc tensor(0.0234, device='cuda:0')
# [3,    50] loss: 2.593
# current batch acc tensor(0.0469, device='cuda:0')
# [3,    51] loss: 2.586
# current batch acc tensor(0.0469, device='cuda:0')
# [3,    52] loss: 2.903
# current batch acc tensor(0.0234, device='cuda:0')
# [3,    53] loss: 2.564
# current batch acc tensor(0.0391, device='cuda:0')
# [3,    54] loss: 2.698
# current batch acc tensor(0.0469, device='cuda:0')
# [3,    55] loss: 2.721
# current batch acc tensor(0.0391, device='cuda:0')
# [3,    56] loss: 2.672
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    57] loss: 2.373
# current batch acc tensor(0.0469, device='cuda:0')
# [3,    58] loss: 2.516
# current batch acc tensor(0.0469, device='cuda:0')
# [3,    59] loss: 2.598
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    60] loss: 2.583
# current batch acc tensor(0.0547, device='cuda:0')
# [3,    61] loss: 2.438
# current batch acc tensor(0.0469, device='cuda:0')
# [3,    62] loss: 2.422
# current batch acc tensor(0.0469, device='cuda:0')
# [3,    63] loss: 2.380
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    64] loss: 2.610
# current batch acc tensor(0.0156, device='cuda:0')
# [3,    65] loss: 2.628
# current batch acc tensor(0.0391, device='cuda:0')
# [3,    66] loss: 2.727
# current batch acc tensor(0.0078, device='cuda:0')
# [3,    67] loss: 2.661
# current batch acc tensor(0.0156, device='cuda:0')
# [3,    68] loss: 2.964
# current batch acc tensor(0.0391, device='cuda:0')
# [3,    69] loss: 2.563
# current batch acc tensor(0.0391, device='cuda:0')
# [3,    70] loss: 2.383
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    71] loss: 2.530
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    72] loss: 2.370
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    73] loss: 2.651
# current batch acc tensor(0.0234, device='cuda:0')
# [3,    74] loss: 2.420
# current batch acc tensor(0.0078, device='cuda:0')
# [3,    75] loss: 2.732
# current batch acc tensor(0.0469, device='cuda:0')
# [3,    76] loss: 2.388
# current batch acc tensor(0.0234, device='cuda:0')
# [3,    77] loss: 2.601
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    78] loss: 2.495
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    79] loss: 2.605
# current batch acc tensor(0.0234, device='cuda:0')
# [3,    80] loss: 2.584
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    81] loss: 2.480
# current batch acc tensor(0.0469, device='cuda:0')
# [3,    82] loss: 2.409
# current batch acc tensor(0.0078, device='cuda:0')
# [3,    83] loss: 2.506
# current batch acc tensor(0.0625, device='cuda:0')
# [3,    84] loss: 2.564
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    85] loss: 2.542
# current batch acc tensor(0.0391, device='cuda:0')
# [3,    86] loss: 2.400
# current batch acc tensor(0.0156, device='cuda:0')
# [3,    87] loss: 2.653
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    88] loss: 2.499
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    89] loss: 2.519
# current batch acc tensor(0.0156, device='cuda:0')
# [3,    90] loss: 2.460
# current batch acc tensor(0.0391, device='cuda:0')
# [3,    91] loss: 2.588
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    92] loss: 2.460
# current batch acc tensor(0.0156, device='cuda:0')
# [3,    93] loss: 2.539
# current batch acc tensor(0.0312, device='cuda:0')
# [3,    94] loss: 2.505
# current batch acc tensor(0.0625, device='cuda:0')
# [3,    95] loss: 2.614
# current batch acc tensor(0.0234, device='cuda:0')
# [3,    96] loss: 2.590
# current batch acc tensor(0.0078, device='cuda:0')
# [3,    97] loss: 2.637
# current batch acc tensor(0.0625, device='cuda:0')
# [3,    98] loss: 2.543
# current batch acc tensor(0.0078, device='cuda:0')
# [3,    99] loss: 2.717
# current batch acc tensor(0.0703, device='cuda:0')
# [3,   100] loss: 2.482
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   101] loss: 2.424
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   102] loss: 2.416
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   103] loss: 2.745
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   104] loss: 2.557
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   105] loss: 2.435
# current batch acc tensor(0.0625, device='cuda:0')
# [3,   106] loss: 2.707
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   107] loss: 2.367
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   108] loss: 2.678
# current batch acc tensor(0.0391, device='cuda:0')
# [3,   109] loss: 2.993
# current batch acc tensor(0.0391, device='cuda:0')
# [3,   110] loss: 2.734
# current batch acc tensor(0.0625, device='cuda:0')
# [3,   111] loss: 2.763
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   112] loss: 2.631
# current batch acc tensor(0.0391, device='cuda:0')
# [3,   113] loss: 2.427
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   114] loss: 2.756
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   115] loss: 2.597
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   116] loss: 2.437
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   117] loss: 2.677
# current batch acc tensor(0.0469, device='cuda:0')
# [3,   118] loss: 2.537
# current batch acc tensor(0.0078, device='cuda:0')
# [3,   119] loss: 2.567
# current batch acc tensor(0.0547, device='cuda:0')
# [3,   120] loss: 2.544
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   121] loss: 2.523
# current batch acc tensor(0.0391, device='cuda:0')
# [3,   122] loss: 2.606
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   123] loss: 2.720
# current batch acc tensor(0.0469, device='cuda:0')
# [3,   124] loss: 2.625
# current batch acc tensor(0.0156, device='cuda:0')
# [3,   125] loss: 2.510
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   126] loss: 2.298
# current batch acc tensor(0.0391, device='cuda:0')
# [3,   127] loss: 2.493
# current batch acc tensor(0.0156, device='cuda:0')
# [3,   128] loss: 2.469
# current batch acc tensor(0.0391, device='cuda:0')
# [3,   129] loss: 2.725
# current batch acc tensor(0.0469, device='cuda:0')
# [3,   130] loss: 2.859
# current batch acc tensor(0.0156, device='cuda:0')
# [3,   131] loss: 2.455
# current batch acc tensor(0.0547, device='cuda:0')
# [3,   132] loss: 2.427
# current batch acc tensor(0., device='cuda:0')
# [3,   133] loss: 2.563
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   134] loss: 2.752
# current batch acc tensor(0.0156, device='cuda:0')
# [3,   135] loss: 2.610
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   136] loss: 2.512
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   137] loss: 2.409
# current batch acc tensor(0.0078, device='cuda:0')
# [3,   138] loss: 2.268
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   139] loss: 2.551
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   140] loss: 2.656
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   141] loss: 2.527
# current batch acc tensor(0.0078, device='cuda:0')
# [3,   142] loss: 2.434
# current batch acc tensor(0.0547, device='cuda:0')
# [3,   143] loss: 2.469
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   144] loss: 2.285
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   145] loss: 2.690
# current batch acc tensor(0.0078, device='cuda:0')
# [3,   146] loss: 2.642
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   147] loss: 2.521
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   148] loss: 2.397
# current batch acc tensor(0.0547, device='cuda:0')
# [3,   149] loss: 2.380
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   150] loss: 2.631
# current batch acc tensor(0.0156, device='cuda:0')
# [3,   151] loss: 2.482
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   152] loss: 2.498
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   153] loss: 2.425
# current batch acc tensor(0.0547, device='cuda:0')
# [3,   154] loss: 2.463
# current batch acc tensor(0.0156, device='cuda:0')
# [3,   155] loss: 2.123
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   156] loss: 2.385
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   157] loss: 2.378
# current batch acc tensor(0.0156, device='cuda:0')
# [3,   158] loss: 2.448
# current batch acc tensor(0.0156, device='cuda:0')
# [3,   159] loss: 2.439
# current batch acc tensor(0.0391, device='cuda:0')
# [3,   160] loss: 2.713
# current batch acc tensor(0.0156, device='cuda:0')
# [3,   161] loss: 2.413
# current batch acc tensor(0.0078, device='cuda:0')
# [3,   162] loss: 2.374
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   163] loss: 2.347
# current batch acc tensor(0.0156, device='cuda:0')
# [3,   164] loss: 2.691
# current batch acc tensor(0.0078, device='cuda:0')
# [3,   165] loss: 2.481
# current batch acc tensor(0.0156, device='cuda:0')
# [3,   166] loss: 2.412
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   167] loss: 2.589
# current batch acc tensor(0., device='cuda:0')
# [3,   168] loss: 2.456
# current batch acc tensor(0.0547, device='cuda:0')
# [3,   169] loss: 2.376
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   170] loss: 2.352
# current batch acc tensor(0.0391, device='cuda:0')
# [3,   171] loss: 2.212
# current batch acc tensor(0.0859, device='cuda:0')
# [3,   172] loss: 2.377
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   173] loss: 2.497
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   174] loss: 2.496
# current batch acc tensor(0.0781, device='cuda:0')
# [3,   175] loss: 2.396
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   176] loss: 2.530
# current batch acc tensor(0.0078, device='cuda:0')
# [3,   177] loss: 2.545
# current batch acc tensor(0.0156, device='cuda:0')
# [3,   178] loss: 2.505
# current batch acc tensor(0.0469, device='cuda:0')
# [3,   179] loss: 2.539
# current batch acc tensor(0.0312, device='cuda:0')
# [3,   180] loss: 2.235
# current batch acc tensor(0.0234, device='cuda:0')
# [3,   181] loss: 2.513
# ...
# current batch acc tensor(0.0078, device='cuda:0')
# [20,    20] loss: 0.062
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    21] loss: 0.016
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    22] loss: 0.100
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    23] loss: 0.061
# current batch acc tensor(0.0156, device='cuda:0')
# [20,    24] loss: 0.062
# current batch acc tensor(0.0391, device='cuda:0')
# [20,    25] loss: 0.016
# current batch acc tensor(0.0469, device='cuda:0')
# [20,    26] loss: 0.063
# current batch acc tensor(0.0547, device='cuda:0')
# [20,    27] loss: 0.016
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    28] loss: 0.019
# current batch acc tensor(0.0156, device='cuda:0')
# [20,    29] loss: 0.091
# current batch acc tensor(0.0312, device='cuda:0')
# [20,    30] loss: 0.024
# current batch acc tensor(0.0156, device='cuda:0')
# [20,    31] loss: 0.022
# current batch acc tensor(0.0078, device='cuda:0')
# [20,    32] loss: 0.050
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    33] loss: 0.051
# current batch acc tensor(0.0078, device='cuda:0')
# [20,    34] loss: 0.016
# current batch acc tensor(0.0078, device='cuda:0')
# [20,    35] loss: 0.025
# current batch acc tensor(0.0312, device='cuda:0')
# [20,    36] loss: 0.013
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    37] loss: 0.079
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    38] loss: 0.015
# current batch acc tensor(0.0078, device='cuda:0')
# [20,    39] loss: 0.030
# current batch acc tensor(0.0078, device='cuda:0')
# [20,    40] loss: 0.038
# current batch acc tensor(0.0391, device='cuda:0')
# [20,    41] loss: 0.030
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    42] loss: 0.021
# current batch acc tensor(0.0547, device='cuda:0')
# [20,    43] loss: 0.021
# current batch acc tensor(0.0391, device='cuda:0')
# [20,    44] loss: 0.019
# current batch acc tensor(0.0391, device='cuda:0')
# [20,    45] loss: 0.031
# current batch acc tensor(0.0156, device='cuda:0')
# [20,    46] loss: 0.021
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    47] loss: 0.019
# current batch acc tensor(0.0312, device='cuda:0')
# [20,    48] loss: 0.054
# current batch acc tensor(0.0547, device='cuda:0')
# [20,    49] loss: 0.010
# current batch acc tensor(0.0469, device='cuda:0')
# [20,    50] loss: 0.023
# current batch acc tensor(0.0156, device='cuda:0')
# [20,    51] loss: 0.014
# current batch acc tensor(0.0156, device='cuda:0')
# [20,    52] loss: 0.006
# current batch acc tensor(0.0156, device='cuda:0')
# [20,    53] loss: 0.021
# current batch acc tensor(0.0391, device='cuda:0')
# [20,    54] loss: 0.088
# current batch acc tensor(0.0469, device='cuda:0')
# [20,    55] loss: 0.034
# current batch acc tensor(0.0391, device='cuda:0')
# [20,    56] loss: 0.010
# current batch acc tensor(0.0312, device='cuda:0')
# [20,    57] loss: 0.032
# current batch acc tensor(0.0469, device='cuda:0')
# [20,    58] loss: 0.009
# current batch acc tensor(0.0469, device='cuda:0')
# [20,    59] loss: 0.020
# current batch acc tensor(0.0391, device='cuda:0')
# [20,    60] loss: 0.024
# current batch acc tensor(0.0547, device='cuda:0')
# [20,    61] loss: 0.027
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    62] loss: 0.007
# current batch acc tensor(0.0156, device='cuda:0')
# [20,    63] loss: 0.015
# current batch acc tensor(0.0312, device='cuda:0')
# [20,    64] loss: 0.013
# current batch acc tensor(0.0312, device='cuda:0')
# [20,    65] loss: 0.006
# current batch acc tensor(0.0078, device='cuda:0')
# [20,    66] loss: 0.044
# current batch acc tensor(0.0156, device='cuda:0')
# [20,    67] loss: 0.062
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    68] loss: 0.018
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    69] loss: 0.016
# current batch acc tensor(0.0078, device='cuda:0')
# [20,    70] loss: 0.010
# current batch acc tensor(0.0312, device='cuda:0')
# [20,    71] loss: 0.013
# current batch acc tensor(0.0312, device='cuda:0')
# [20,    72] loss: 0.054
# current batch acc tensor(0.0391, device='cuda:0')
# [20,    73] loss: 0.013
# current batch acc tensor(0.0391, device='cuda:0')
# [20,    74] loss: 0.020
# current batch acc tensor(0.0078, device='cuda:0')
# [20,    75] loss: 0.015
# current batch acc tensor(0.0469, device='cuda:0')
# [20,    76] loss: 0.110
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    77] loss: 0.013
# current batch acc tensor(0.0078, device='cuda:0')
# [20,    78] loss: 0.016
# current batch acc tensor(0.0156, device='cuda:0')
# [20,    79] loss: 0.016
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    80] loss: 0.029
# current batch acc tensor(0.0312, device='cuda:0')
# [20,    81] loss: 0.074
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    82] loss: 0.022
# current batch acc tensor(0.0156, device='cuda:0')
# [20,    83] loss: 0.044
# current batch acc tensor(0.0625, device='cuda:0')
# [20,    84] loss: 0.017
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    85] loss: 0.117
# current batch acc tensor(0.0391, device='cuda:0')
# [20,    86] loss: 0.034
# current batch acc tensor(0.0156, device='cuda:0')
# [20,    87] loss: 0.036
# current batch acc tensor(0.0312, device='cuda:0')
# [20,    88] loss: 0.048
# current batch acc tensor(0.0312, device='cuda:0')
# [20,    89] loss: 0.046
# current batch acc tensor(0.0703, device='cuda:0')
# [20,    90] loss: 0.036
# current batch acc tensor(0.0391, device='cuda:0')
# [20,    91] loss: 0.016
# current batch acc tensor(0.0156, device='cuda:0')
# [20,    92] loss: 0.007
# current batch acc tensor(0.0156, device='cuda:0')
# [20,    93] loss: 0.021
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    94] loss: 0.021
# current batch acc tensor(0.0625, device='cuda:0')
# [20,    95] loss: 0.038
# current batch acc tensor(0.0078, device='cuda:0')
# [20,    96] loss: 0.063
# current batch acc tensor(0.0391, device='cuda:0')
# [20,    97] loss: 0.056
# current batch acc tensor(0.0625, device='cuda:0')
# [20,    98] loss: 0.027
# current batch acc tensor(0.0234, device='cuda:0')
# [20,    99] loss: 0.041
# current batch acc tensor(0.0703, device='cuda:0')
# [20,   100] loss: 0.048
# current batch acc tensor(0.0156, device='cuda:0')
# [20,   101] loss: 0.015
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   102] loss: 0.019
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   103] loss: 0.029
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   104] loss: 0.006
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   105] loss: 0.015
# current batch acc tensor(0.0625, device='cuda:0')
# [20,   106] loss: 0.038
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   107] loss: 0.004
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   108] loss: 0.028
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   109] loss: 0.079
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   110] loss: 0.062
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   111] loss: 0.055
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   112] loss: 0.051
# current batch acc tensor(0.0156, device='cuda:0')
# [20,   113] loss: 0.022
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   114] loss: 0.024
# current batch acc tensor(0.0156, device='cuda:0')
# [20,   115] loss: 0.043
# current batch acc tensor(0.0156, device='cuda:0')
# [20,   116] loss: 0.030
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   117] loss: 0.040
# current batch acc tensor(0.0469, device='cuda:0')
# [20,   118] loss: 0.089
# current batch acc tensor(0.0703, device='cuda:0')
# [20,   119] loss: 0.095
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   120] loss: 0.030
# current batch acc tensor(0.0469, device='cuda:0')
# [20,   121] loss: 0.043
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   122] loss: 0.049
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   123] loss: 0.038
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   124] loss: 0.022
# current batch acc tensor(0.0469, device='cuda:0')
# [20,   125] loss: 0.054
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   126] loss: 0.009
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   127] loss: 0.028
# current batch acc tensor(0.0156, device='cuda:0')
# [20,   128] loss: 0.026
# current batch acc tensor(0.0156, device='cuda:0')
# [20,   129] loss: 0.022
# current batch acc tensor(0.0469, device='cuda:0')
# [20,   130] loss: 0.067
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   131] loss: 0.015
# current batch acc tensor(0.0547, device='cuda:0')
# [20,   132] loss: 0.015
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   133] loss: 0.017
# current batch acc tensor(0.0156, device='cuda:0')
# [20,   134] loss: 0.082
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   135] loss: 0.017
# current batch acc tensor(0.0547, device='cuda:0')
# [20,   136] loss: 0.050
# current batch acc tensor(0.0547, device='cuda:0')
# [20,   137] loss: 0.078
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   138] loss: 0.029
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   139] loss: 0.027
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   140] loss: 0.022
# current batch acc tensor(0.0078, device='cuda:0')
# [20,   141] loss: 0.060
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   142] loss: 0.025
# current batch acc tensor(0.0547, device='cuda:0')
# [20,   143] loss: 0.039
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   144] loss: 0.075
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   145] loss: 0.067
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   146] loss: 0.072
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   147] loss: 0.014
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   148] loss: 0.132
# current batch acc tensor(0.0547, device='cuda:0')
# [20,   149] loss: 0.027
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   150] loss: 0.014
# current batch acc tensor(0.0156, device='cuda:0')
# [20,   151] loss: 0.066
# current batch acc tensor(0.0547, device='cuda:0')
# [20,   152] loss: 0.041
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   153] loss: 0.025
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   154] loss: 0.045
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   155] loss: 0.055
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   156] loss: 0.137
# current batch acc tensor(0.0078, device='cuda:0')
# [20,   157] loss: 0.020
# current batch acc tensor(0.0156, device='cuda:0')
# [20,   158] loss: 0.049
# current batch acc tensor(0.0078, device='cuda:0')
# [20,   159] loss: 0.023
# current batch acc tensor(0.0469, device='cuda:0')
# [20,   160] loss: 0.010
# current batch acc tensor(0.0625, device='cuda:0')
# [20,   161] loss: 0.024
# current batch acc tensor(0.0078, device='cuda:0')
# [20,   162] loss: 0.036
# current batch acc tensor(0.0469, device='cuda:0')
# [20,   163] loss: 0.035
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   164] loss: 0.028
# current batch acc tensor(0.0469, device='cuda:0')
# [20,   165] loss: 0.042
# current batch acc tensor(0.0625, device='cuda:0')
# [20,   166] loss: 0.057
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   167] loss: 0.029
# current batch acc tensor(0.0781, device='cuda:0')
# [20,   168] loss: 0.057
# current batch acc tensor(0.0547, device='cuda:0')
# [20,   169] loss: 0.092
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   170] loss: 0.063
# current batch acc tensor(0.0078, device='cuda:0')
# [20,   171] loss: 0.029
# current batch acc tensor(0.0859, device='cuda:0')
# [20,   172] loss: 0.013
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   173] loss: 0.170
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   174] loss: 0.056
# current batch acc tensor(0.0781, device='cuda:0')
# [20,   175] loss: 0.035
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   176] loss: 0.057
# current batch acc tensor(0.0078, device='cuda:0')
# [20,   177] loss: 0.008
# current batch acc tensor(0.0469, device='cuda:0')
# [20,   178] loss: 0.024
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   179] loss: 0.009
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   180] loss: 0.134
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   181] loss: 0.115
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   182] loss: 0.021
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   183] loss: 0.053
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   184] loss: 0.036
# current batch acc tensor(0.0156, device='cuda:0')
# [20,   185] loss: 0.077
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   186] loss: 0.010
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   187] loss: 0.028
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   188] loss: 0.022
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   189] loss: 0.104
# current batch acc tensor(0.0469, device='cuda:0')
# [20,   190] loss: 0.035
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   191] loss: 0.042
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   192] loss: 0.130
# current batch acc tensor(0.0547, device='cuda:0')
# [20,   193] loss: 0.106
# current batch acc tensor(0.0078, device='cuda:0')
# [20,   194] loss: 0.101
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   195] loss: 0.121
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   196] loss: 0.010
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   197] loss: 0.080
# current batch acc tensor(0.0547, device='cuda:0')
# [20,   198] loss: 0.184
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   199] loss: 0.031
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   200] loss: 0.009
# current batch acc tensor(0.0703, device='cuda:0')
# [20,   201] loss: 0.039
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   202] loss: 0.044
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   203] loss: 0.036
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   204] loss: 0.044
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   205] loss: 0.137
# current batch acc tensor(0.0156, device='cuda:0')
# [20,   206] loss: 0.072
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   207] loss: 0.044
# current batch acc tensor(0.0859, device='cuda:0')
# [20,   208] loss: 0.004
# current batch acc tensor(0.0469, device='cuda:0')
# [20,   209] loss: 0.035
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   210] loss: 0.013
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   211] loss: 0.030
# current batch acc tensor(0.0547, device='cuda:0')
# [20,   212] loss: 0.168
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   213] loss: 0.043
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   214] loss: 0.019
# current batch acc tensor(0.0156, device='cuda:0')
# [20,   215] loss: 0.118
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   216] loss: 0.077
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   217] loss: 0.172
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   218] loss: 0.014
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   219] loss: 0.037
# current batch acc tensor(0.0156, device='cuda:0')
# [20,   220] loss: 0.056
# current batch acc tensor(0.0547, device='cuda:0')
# [20,   221] loss: 0.038
# current batch acc tensor(0.0156, device='cuda:0')
# [20,   222] loss: 0.076
# current batch acc tensor(0.0078, device='cuda:0')
# [20,   223] loss: 0.067
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   224] loss: 0.031
# current batch acc tensor(0.0078, device='cuda:0')
# [20,   225] loss: 0.085
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   226] loss: 0.081
# current batch acc tensor(0.0078, device='cuda:0')
# [20,   227] loss: 0.170
# current batch acc tensor(0.0469, device='cuda:0')
# [20,   228] loss: 0.070
# current batch acc tensor(0.0156, device='cuda:0')
# [20,   229] loss: 0.056
# current batch acc tensor(0.0312, device='cuda:0')
# [20,   230] loss: 0.053
# current batch acc tensor(0.0234, device='cuda:0')
# [20,   231] loss: 0.024
# current batch acc tensor(0.0547, device='cuda:0')
# [20,   232] loss: 0.034
# current batch acc tensor(0.0391, device='cuda:0')
# [20,   233] loss: 0.042
# current batch acc tensor(0.0156, device='cuda:0')
# [20,   234] loss: 0.000
# current batch acc tensor(0.0625, device='cuda:0')
# Finished Training of AlexNet

# %% [markdown]
# ### Test ###

# %%
correct = 0
total = 0
wrong_pred =[]
right_label = []
with torch.no_grad():
    for data in test_loader:
        images = data[0].to(device)
        labels = label_to_num(data[1]).to(device)
        outputs = AlexNet_model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        
        for i in range(0,len(predicted)):
              if predicted[i].item() != labels[i].item():
                    wrong_pred.append(predicted[i].item())
                    right_label.append(labels[i].item())
        

        
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the test images: 34 %

# %% [markdown]
# ###   Analyse  ###

# %%
nb_label_wrongpred = []
for i in range(0,50):
    nb_label_wrongpred.append(right_label.count(i))

# %%
list_animal = list(dict_label_animal.keys())

# %%
plt.bar(range(50),nb_label_wrongpred)
plt.show()

# %%
good_classification = []
bad_classification = []
for i in range(50):
    if nb_label_wrongpred[i]<=5:
        good_classification.append(i)
    if    nb_label_wrongpred[i]>=60:
        bad_classification.append(i)

# %%
def find_right_animal(m):
    wrong_pred_m =[]
    for j in [i for i,x in enumerate(right_label) if x == m]:
        wrong_pred_m.append(wrong_pred[j])
    return list_animal[max(wrong_pred_m,key = wrong_pred_m.count)]

# %%
for i in good_classification :
    print('Alexnet a bien classifie '+animals[i])

# %%
for i in bad_classification:
    print('Alexnet a mal classifie '+animals[i]+' , melange souvent avec '+find_right_animal(i))
# Out:
# Alexnet a mal classifie antelope , melange souvent avec deer
# Alexnet a mal classifie grizzly+bear , melange souvent avec buffalo
# Alexnet a mal classifie persian+cat , melange souvent avec hamster
# Alexnet a mal classifie horse , melange souvent avec buffalo
# Alexnet a mal classifie german+shepherd , melange souvent avec grizzly+bear
# Alexnet a mal classifie siamese+cat , melange souvent avec hamster
# Alexnet a mal classifie tiger , melange souvent avec leopard
# Alexnet a mal classifie hippopotamus , melange souvent avec seal
# Alexnet a mal classifie moose , melange souvent avec buffalo
# Alexnet a mal classifie humpback+whale , melange souvent avec blue+whale
# Alexnet a mal classifie elephant , melange souvent avec buffalo
# Alexnet a mal classifie gorilla , melange souvent avec chimpanzee
# Alexnet a mal classifie ox , melange souvent avec buffalo
# Alexnet a mal classifie fox , melange souvent avec rabbit
# Alexnet a mal classifie sheep , melange souvent avec horse
# Alexnet a mal classifie seal , melange souvent avec hippopotamus
# Alexnet a mal classifie chimpanzee , melange souvent avec gorilla
# Alexnet a mal classifie hamster , melange souvent avec persian+cat
# Alexnet a mal classifie squirrel , melange souvent avec hamster
# Alexnet a mal classifie rhinoceros , melange souvent avec hippopotamus
# Alexnet a mal classifie rabbit , melange souvent avec persian+cat
# Alexnet a mal classifie bat , melange souvent avec hamster
# Alexnet a mal classifie giraffe , melange souvent avec horse
# Alexnet a mal classifie wolf , melange souvent avec lion
# Alexnet a mal classifie chihuahua , melange souvent avec hamster
# Alexnet a mal classifie otter , melange souvent avec seal
# Alexnet a mal classifie buffalo , melange souvent avec grizzly+bear
# Alexnet a mal classifie deer , melange souvent avec antelope
# Alexnet a mal classifie bobcat , melange souvent avec rabbit
# Alexnet a mal classifie pig , melange souvent avec hamster
# Alexnet a mal classifie lion , melange souvent avec rabbit
# Alexnet a mal classifie polar+bear , melange souvent avec seal
# Alexnet a mal classifie collie , melange souvent avec german+shepherd
# Alexnet a mal classifie raccoon , melange souvent avec german+shepherd
# Alexnet a mal classifie cow , melange souvent avec horse
# Alexnet a mal classifie dolphin , melange souvent avec hippopotamus

# %%
anno = pd.read_csv("annotations.csv",header=None)[1]

# %%
anno_list =list(anno)

# %%
for animal in animals:
    print("Il y a " + str(anno_list.count(animal)) +" "+ animal  )
# Out:
# Il y a 1046 antelope
# Il y a 852 grizzly+bear
# Il y a 291 killer+whale
# Il y a 193 beaver
# Il y a 549 dalmatian
# Il y a 747 persian+cat
# Il y a 1645 horse
# Il y a 1033 german+shepherd
# Il y a 174 blue+whale
# Il y a 500 siamese+cat
# Il y a 188 skunk
# Il y a 100 mole
# Il y a 877 tiger
# Il y a 684 hippopotamus
# Il y a 720 leopard
# Il y a 704 moose
# Il y a 291 spider+monkey
# Il y a 709 humpback+whale
# Il y a 1038 elephant
# Il y a 872 gorilla
# Il y a 728 ox
# Il y a 664 fox
# Il y a 1420 sheep
# Il y a 988 seal
# Il y a 728 chimpanzee
# Il y a 779 hamster
# Il y a 1200 squirrel
# Il y a 696 rhinoceros
# Il y a 1088 rabbit
# Il y a 383 bat
# Il y a 1202 giraffe
# Il y a 589 wolf
# Il y a 567 chihuahua
# Il y a 310 rat
# Il y a 272 weasel
# Il y a 758 otter
# Il y a 895 buffalo
# Il y a 1170 zebra
# Il y a 874 giant+panda
# Il y a 1344 deer
# Il y a 630 bobcat
# Il y a 713 pig
# Il y a 1019 lion
# Il y a 185 mouse
# Il y a 868 polar+bear
# Il y a 1028 collie
# Il y a 215 walrus
# Il y a 512 raccoon
# Il y a 1338 cow
# Il y a 946 dolphin

# %% [markdown]
# ### Conclusion ###

# %% [markdown]
# Alexnet a une très bien performance en classification des animaux. Mais il a même la difficulté à classifer deux animaux similaires.
# À faire:
# 1.Étudier si VIT a une meilleure performance à classifer deux animaux similaire.
# 2.Essayer de comprendre la logique de la construction de AlexNet
